# %%
import pickle
import pandas as pd
def load_pickle(file_path):
    file = open(file_path, 'rb')
    pred_data = pickle.load(file)
    file.close()
    return pred_data

# %%
pred_data = load_pickle("../data/5_mil_7days_metoo.p")

# %%
pred_data
# Out:
#                               _id  \
# 0        5e7d03e7230443859100163d
# 1        5e7d03e72304438591001642
# 2        5e7d03e72304438591001647
# 3        5e7d03e72304438591001649
# 4        5e7d03e7230443859100164c
# ...                           ...
# 4683900  5e7d23342304438591e1e340
# 4683901  5e7d23342304438591e1e346
# 4683902  5e7d23342304438591e1e347
# 4683903  5e7d23342304438591e1e34c
# 4683904  5e7d23342304438591e1e34d
#
#                                                       body  \
# 0        @TheFirstBladc » “I do love you. . I love you,...
# 1        I haven't seen &amp; nobody's confide in me re...
# 2        Exempleado de Miramax habla de Harvey Weinstei...
# 3                           @SabiieeyyCel Sweet naman besh
# 4        Mark Halperin apologizes for 'aggressive and c...
# ...                                                    ...
# 4683900  But but but dude you're a rapist HOW IS THIS E...
# 4683901  Lisa Bloom, Lawyer Advising Harvey Weinstein, ...
# ...

# %% [markdown]
# ### Valid 7-day counts

# %%
valid_counts_df = pd.read_csv("../data/target_valid_time_7days.csv")

# %%
valid_counts_df
# Out:
#              target   count
# 0            ratner   19461
# 1            weiner   16419
# 2            savino    1323
# 3        david_corn    1863
# 4   russell_simmons     182
# 5           mendoza    4082
# 6        heatherton      96
# 7           oreskes    3491
# 8           goddard    4920
# 9         weinstein  606017
# 10           wenner    1157
# 11         dreyfuss    4821
# 12         louis_ck  140140
# 13           tambor    3803
# 14           seagal    9537
# 15           toback   19184
# 16        bocanegra     210
# 17        landesman     617
# 18        masterson    5854
# 19          schwahn    3122
# 20      howie_rubin     261
# 21        ken_baker     507
# 22   david_marchant      58
# 23            takei   31074
# 24           blaine    5938
# 25            piven    6212
# 26   caleb_jennings       7
# 27            metoo       0
# 28           scoble    3936
# 29            nelly    4161
# 30       wieseltier    2914
# 31       ethan_kath    1313
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure(figsize=(20, 2))
ax = fig.add_subplot(111)

# %%
ax = valid_counts_df.plot.bar(x='target', y='count')

# %%
# import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots(figsize=(30,12))
ax.bar(list(valid_counts_df.target),list(valid_counts_df["count"]))
ax.set_xticklabels(list(valid_counts_df.target), Fontsize=20, rotation=90)
ax.set_xlabel("Target", Fontsize="20")
ax.set_ylabel("Number of tweets in a week following the article", Fontsize="20")
# ax.set_yticklabels(ax.get_ylabel)Fontsize=20, rotation=90)

plt.show()
# Out:
# /home/geev/Research/in_progress/Transgressions/transgressions-env/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   """
# /home/geev/Research/in_progress/Transgressions/transgressions-env/lib/python3.6/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   """
# /home/geev/Research/in_progress/Transgressions/transgressions-env/lib/python3.6/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#
# /home/geev/Research/in_progress/Transgressions/transgressions-env/lib/python3.6/site-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   import sys

# %%
fig.savefig("../result/plots/time_check_count.png", bbox_inches="tight")

# %% [markdown]
# ## Text Length
