# %%
from process_tweets import *

# %%
targs = pd.read_csv('../../data/transgression_ambiguity_metoo_breaking_stimuli_all_targets.csv').target.values

# %%
# Out:
# bad nelly
# too long or too short dwayne_duron_marshall
# too long or too short lars_von_trier
# too long or too short neil_degrasse_tyson
# too long or too short steven_wilder_striegel

# %%
len(all_targets_list)
# Out:
# 246

# %%
with open("../../data/target_dic.json", "r") as f:
    target_dic = json.load(f)

# %%
len(target_dic)
# Out:
# 48

# %%
import re
# import nltk
import datetime
import json
import gzip
import os
import pickle
import unidecode
import pprint
from tqdm import tqdm
import numpy as np
from dateutil.parser import parse
from pymongo import MongoClient
import pandas as pd
from names_dataset import NameDataset
# from whatthelang import WhatTheLang

from pymongo.errors import BulkWriteError, CursorNotFound
import pymongo

class NewTweetPreprocessor():
    def __init__(self,  all_targets_list, target_dic, db_name="jason_twitter", collection_name="tweets"):
#         self.tweet_data_path = tweet_data_path
#         self.files = os.listdir(self.tweet_data_path)
        self.client = MongoClient()
        self.db_metoo_tweets = self.client["jason_twitter"]
        self.metoo_tweets = self.db_metoo_tweets[collection_name]
        self.namedb = NameDataset()
        self.all_targets_list = all_targets_list
        self.target_dic = target_dic # ln, fn, handle
        self.set_target_regex_dic()
        self.target_last_names = [self.target_dic[k]['ln'] for k in self.target_dic.keys()]
        self.target_gold_name =  {}
        for k in self.targ_dic.keys():
            self.target_gold_name[k] = self.targ_dic[k].pattern.split('|')[0].title()
        self.build_target_article_dates()
        # self.wtl = WhatTheLang()


    def build_target_article_dates(self, vox_data_path='../../data/vox_accusation_data.csv', window_days = 7):
        """
        sets self.target_date
        builds a dictionary of the acceptable date range for each target
        """
        self.target_date = {}

        for k in self.targ_dic.keys():
            self.target_date[k] = {}
            self.target_date[k]['name'] = self.targ_dic[k].pattern.split('|')[0].title().lower()

        vox_data = pd.read_csv(vox_data_path)
        vox_data['public_datetime'] = pd.to_datetime(vox_data.public_date, format='%B %d, %Y')
        vox_data['name_string'] = vox_data.name.str.replace(' ', '_')

        for k in self.target_date.keys():
            time = vox_data[vox_data.name == self.target_date[k]['name']].public_datetime.values

            time = (time - np.datetime64('1970-01-01')) / np.timedelta64(1, 's')
            try:
                time = datetime.datetime.utcfromtimestamp(time[0])
                self.target_date[k]['min_date'] = time
                self.target_date[k]['max_date'] = time + datetime.timedelta(days=window_days)
            except:
                pass
                print("failed to build date for {}".format(k))
                # print(k)

        self.target_date['ck']['min_date'] = datetime.datetime.strptime('November 9, 2017', '%B %d, %Y')
        self.target_date['ck']['max_date'] = datetime.datetime.strptime('November 9, 2017',
                                                                   '%B %d, %Y') + datetime.timedelta(days=window_days)

    def check_date(self, target, postedTime):
        """
        returns True/False
        Checks if the posted time lies within acceptable window for the target
        """
        try:
            if postedTime >= self.target_date[target]['min_date'] and postedTime <= self.target_date[target]['max_date']:
                return (True)
            else:
                return (False)
        except:
            print("exception in check_date for {}".format(target))
            return (None)

    def check_target_dates(self, tweet):
        """
        Checks if the tweet is within time window of first articles of all targets mentioned in the tweet
        """
        targets = self.get_targets(tweet)
        time_check = {}
        for target in targets:
            if target == 'metoo':
                continue
            else:

                if 'weinstein' in target:
                    if target == 'weinstein':
                        target2 = 'harvey_weinstein'
                    else:
                        target2 = target
                else:
                    target2 = target.split('_')[-1]

                #             elif target == 'roy_price':
                #                 target2 = 'price'

                #             elif target == 'louis_ck':
                #                 target2 = 'ck'

                #             elif target == 'kirt_webster':
                #                 target2 = 'webster'

                #             else:
                #                 target2 = target

                time_check[target] = {}
                valid = self.check_date(target2, tweet['postedTime'])

                if valid is None:
                    return (None)

                time_check[target]['valid'] = valid
                time_check[target]['public_date'] = self.target_date[target2]['min_date']

        tweet['time_check'] = time_check
        return (tweet)

    def get_targets(self, tweet):
        targets = tweet['body_target_mentions']
        try:
            targets += tweet['quoted_status_target_mentions']
        except:
            pass
        try:
            targets += tweet['gnip_url_title_mentions']
        except:
            pass
        targets = self.unique(targets)
        return (targets)

    def set_target_regex_dic(self):
        print("building target regex")
        self.targ_dic = {}
        duplicate_list = ["marshall", "klein", "miller", "weinstein", "moore", "rubin", "jr", "johnson"]
        all_phrases = []
        for target in self.all_targets_list:
            if len(target)==2:
                target = target[0] # to choose the right element from the list
            try:
                split_targ = target.split('_')
                k = split_targ[-1]
                if k in duplicate_list:
                    k = target
#                 if 'harvey' in split_targ:
#                     k = 'harvey_weinstein'

#                 if 'bob' in split_targ and 'weinstein' in split_targ:
#                     k = 'bob_weinstein'
#                     self.targ_dic[k] = re.compile('|'.join(['bob weinstein', 'bobweinstein', 'bob']), re.IGNORECASE)
            
#                 if k in self.targ_dic:
#                     print("already have", k, target)
#                 if len(split_targ)>2:
        
                self.targ_dic[k] = re.compile('|'.join([' '.join(split_targ)] +
                                                       split_targ[1:] +
                                                       [''.join(split_targ)]), re.IGNORECASE)
                
                all_phrases.extend([' '.join(split_targ)] + split_targ[1:] + [''.join(split_targ)])
            
        
#                 else:
#                         self.targ_dic[k] = re.compile('|'.join([' '.join(split_targ)] +
#                                                        [''.join(split_targ)]), re.IGNORECASE)
            except:
                print("failed building regex for ", target)
                pass
        filtered_phrases = [p for p in all_phrases if len(p)>2]
        self.all_targ_regex = re.compile('|'.join(filtered_phrases), re.IGNORECASE)

        self.targ_dic['ck'] = re.compile('|'.join(['louis ck', 'louis c.k.', 'louisck', 'louisc.k.']), re.IGNORECASE)
        self.targ_dic['moore'] = re.compile('|'.join(['roy moore', 'roymoore', 'moore']), re.IGNORECASE)
    def get_new_client(self):
        self.client = MongoClient()
        self.db_metoo_tweets = self.client["new_metoo"]
        self.metoo_tweets = self.db_metoo_tweets.metoo_tweets

    def pickle_db(self, save_path="data/data.p", query={"is_RT":True}):
        cursor = self.metoo_tweets.find(query)
        list_cur = list(cursor)
        df = pd.DataFrame(list_cur)
        file = open(save_path, 'wb')
        pickle.dump(df, file)
        file.close()

    def push_tweets_to_db(self):
        tweets = self.read_tweets(self.files)
        i=0
        user_data = {}
        for tweet in tqdm(tweets):
            cur_tweet_data, user_data = self.process_tweet(tweet, user_data)
            if cur_tweet_data is not None:
                try:
                    temp = self.metoo_tweets.insert_one(cur_tweet_data)
                except:
                   self.get_new_client()
                   temp = self.metoo_tweets.insert_one(cur_tweet_data)

    def read_tweets(self, files):
        n_files = len(files)
        for i, file in enumerate(files):
            # print(f'Working on file: {i} of {n_files}')
            with gzip.open(os.path.join(self.tweet_data_path, file), 'rb') as f:
                for line in f:
                    line = json.loads(line)
                    yield (line)

    def process_user_data(self, tweet_dat, user_data):

        cur_user_id = tweet_dat['actor']['id'].split(':')[-1]

        try:  # See if user data already stored

            user_data[cur_user_id]['n_corpus_tweets'] += 1
            return (user_data)

        except KeyError as e:  # If not stored, get fields

            cur_user_data = {}
            cur_user_data['user_id'] = cur_user_id
            cur_user_data['verb'] = tweet_dat['verb']
            cur_user_data['user_objectType'] = tweet_dat['actor']['objectType']
            cur_user_data['displayName'] = tweet_dat['actor']['displayName']
            cur_user_data['summary'] = tweet_dat['actor']['summary']
            cur_user_data['verified'] = tweet_dat['actor']['verified']
            cur_user_data['statusesCount'] = tweet_dat['actor']['statusesCount']
            cur_user_data['favoritesCount'] = tweet_dat['actor']['favoritesCount']
            cur_user_data['friendsCount'] = tweet_dat['actor']['friendsCount']
            cur_user_data['followersCount'] = tweet_dat['actor']['followersCount']

            try:
                cur_user_data['location'] = tweet_dat['actor']['location']
            except:
                cur_user_data['location'] = None

            cur_user_data['n_corpus_instances'] = 1  # this counts RT @, quote tweets, and posts for this person

            user_data[cur_user_id] = cur_user_data

            return (user_data)

    def process_tweet(self, tweet, user_data):

        try:
            cur_user_id = tweet['actor']['id'].split(':')[-1]

        except:
            return None, user_data

        user_dat = self.process_user_data(tweet, user_data)

        # Get tweet data

        cur_tweet_data = {'body': None, 'postedTime': None, 'retweetCount': None, 'favoritesCount': None,
                          'quoted_status_id': None, 'quoted_status_user_id': None, 'quoted_status_body': None,
                          'quoted_status_user_postedTime': None, 'gnip_url_title': None, 'gnip_url_description': None,
                          'is_RT': False, 'RT_body': None, 'RT_user_id': None, 'RT_id': None,
                          'tweet_id': tweet['id'].split(':')[-1], 'user_id': cur_user_id}

        try:

            cur_tweet_data['body'] = tweet['long_object']['body']

        except:

            cur_tweet_data['body'] = tweet['body']

        cur_tweet_data['postedTime'] = parse(tweet['postedTime'])
        cur_tweet_data['retweetCount'] = tweet['retweetCount']
        if "favoritesCount" in tweet["object"]:
            cur_tweet_data['favoritesCount'] = tweet['object']['favoritesCount']
        else:
            cur_tweet_data['favoritesCount'] = tweet['favoritesCount']

        if cur_tweet_data['body'].startswith('RT @'):
            cur_tweet_data['is_RT'] = True
        # if not cur_tweet_data['is_RT'] and cur_tweet_data['favoritesCount']!=0:
        #     print("found a tweet")
        # else:
        #     print("didn't find it")
        try:
            if tweet['object']:
                user_dat = self.process_user_data(tweet['object'], user_data)

                cur_tweet_data['RT_body'] = tweet['object']['body']
                cur_tweet_data['RT_user_id'] = tweet['object']['actor']['id'].split(':')[-1]
                cur_tweet_data['RT_id'] = tweet['object']['id'].split(':')[-1]

        except:
            pass

        try:
            if tweet['twitter_quoted_status']:
                user_dat = self.process_user_data(tweet['twitter_quoted_status'], user_data)

                cur_tweet_data['quoted_status_id'] = tweet['twitter_quoted_status']['id'].split(':')[-1]
                cur_tweet_data['quoted_status_user_id'] = tweet['twitter_quoted_status']['actor']['id'].split(':')[-1]
                cur_tweet_data['quoted_status_body'] = tweet['twitter_quoted_status']['body']
                cur_tweet_data['quoted_status_user_postedTime'] = parse(tweet['twitter_quoted_status']['postedTime'])
        except:
            pass

        try:
            if tweet['gnip']:
                cur_tweet_data['gnip_url_title'] = []
                cur_tweet_data['gnip_url_description'] = []
                for i in tweet['gnip']['urls']:
                    try:
                        cur_tweet_data['gnip_url_title'].append(i['expanded_url_title'])
                        cur_tweet_data['gnip_url_description'].append(i['expanded_url_description'])

                    except KeyError:
                        pass
        except:
            pass

        return (cur_tweet_data, user_data)

    def validate_name(self, text, cur_targets, target_dic, target_last_names):
        """
            returns a list of targets that have been mentioned in a text by either first name, last name, or handle

                splits the text by " " or "," or "-" then for each target for each token
                1. if it's a mention (starts with @) checks if it matches target handle then target is validated
                2. if it includes either first name or last name of target  then target is validated
                3. if it includes the exclusion list then target is not validated and we move to next target
        """


        split_text = re.split(' |-|,|_', text.lower())
        valid = None
        valid_targets = []

        for cur_target in cur_targets:
            for i, token in enumerate(split_text):
                if cur_target in token:

                    if token.startswith('@') and target_dic[cur_target]['handle'] == token:
                        valid = 1
                    if split_text[i - 1] in target_dic[cur_target]['fn']:
                        valid = 1
                    if split_text[i - 1] in target_last_names:
                        valid = 1
                    if not self.namedb.search_first_name(unidecode.unidecode(split_text[i - 1])):
                        # print("here with", split_text[i-1])
                        valid = 1

                    if split_text[i - 1] in target_dic[cur_target]['other_exclude']:
                        valid = 0

            if valid == 1:
                valid_targets.append(cur_target)
        return (valid_targets)

    def check_target(self, targets, label, text, target_mentions):
        if any(substring in text for substring in targets):
            target_mentions.append(label)
        return (target_mentions)

    def check_targets(self, text):
        text = text.lower()

        target_mentions = []
        #todo: fix
        # target_mentions = self.check_target(['metoo'], 'metoo', text, target_mentions)
        target_mentions = self.check_target(['louis ck', 'louis c.k.', 'louisck'], 'louis_ck', text, target_mentions)
        target_mentions = self.check_target(['kirt webster'], 'kirt_webster', text, target_mentions)
        target_mentions = self.check_target(['nassar'], 'nassar', text, target_mentions)
        target_mentions = self.check_target(['landesman'], 'landesman', text, target_mentions)
        target_mentions = self.check_target(['masterson'], 'masterson', text, target_mentions)
        target_mentions = self.check_target(['scott courtney', 'scottcourtney'], 'scott_courtney', text, target_mentions)
        target_mentions = self.check_target(['affleck'], 'affleck', text, target_mentions)
        target_mentions = self.check_target(['scoble'], 'scoble', text, target_mentions)
        target_mentions = self.check_target(['schwahn'], 'schwahn', text, target_mentions)
        target_mentions = self.check_target(['andy dick', 'andydick'], 'andy_dick', text, target_mentions)
        target_mentions = self.check_target(['venit'], 'venit', text, target_mentions)
        target_mentions = self.check_target(['berganza'], 'berganza', text, target_mentions)
        target_mentions = self.check_target(['seagal'], 'seagal', text, target_mentions)
        target_mentions = self.check_target(['goddard'], 'goddard', text, target_mentions)
        target_mentions = self.check_target(['hafford'], 'hafford', text, target_mentions)
        target_mentions = self.check_target(['halperin'], 'halperin', text, target_mentions)
        target_mentions = self.check_target(['smyre'], 'smyre', text, target_mentions)
        target_mentions = self.check_target(['lebsock'], 'lebsock', text, target_mentions)
        target_mentions = self.check_target(['weinstein'], 'weinstein', text, target_mentions)
        target_mentions = self.check_target(['bob weinstein', 'bobweinstein'], 'bob_weinstein', text, target_mentions)
        target_mentions = self.check_target(['ingenito'], 'ingenito', text, target_mentions)
        target_mentions = self.check_target(['spacey'], 'spacey', text, target_mentions)
        target_mentions = self.check_target(['kreisberg'], 'kreisberg', text, target_mentions)
        target_mentions = self.check_target(['hamilton fish', 'hamiltonfish'], 'hamilton_fish', text, target_mentions)
        target_mentions = self.check_target(['grasham'], 'grasham', text, target_mentions)
        target_mentions = self.check_target(['wieseltier'], 'wieseltier', text, target_mentions)
        target_mentions = self.check_target(['knepper'], 'knepper', text, target_mentions)
        #todo: fix
        # target_mentions = self.check_target(['nelly'], 'nelly', text, target_mentions)
        target_mentions = self.check_target(['ratner'], 'ratner', text, target_mentions)
        target_mentions = self.check_target(['ken baker', 'kenbaker'], 'ken_baker', text, target_mentions)
        target_mentions = self.check_target(['toback'], 'toback', text, target_mentions)
        target_mentions = self.check_target(['dreyfuss'], 'dreyfuss', text, target_mentions)
        target_mentions = self.check_target(['piven'], 'piven', text, target_mentions)
        target_mentions = self.check_target(['weiner'], 'weiner', text, target_mentions)
        target_mentions = self.check_target(['takei'], 'takei', text, target_mentions)
        target_mentions = self.check_target(['ethan kath', 'ethankath'], 'ethan_kath', text, target_mentions)
        target_mentions = self.check_target(['lacey'], 'lacey', text, target_mentions)
        target_mentions = self.check_target(['lockhart steele', 'lockhartsteele'], 'lockhart_steele', text, target_mentions)
        target_mentions = self.check_target(['besh'], 'besh', text, target_mentions)
        target_mentions = self.check_target(['bocanegra'], 'bocanegra', text, target_mentions)
        target_mentions = self.check_target(['wenner'], 'wenner', text, target_mentions)
        target_mentions = self.check_target(['hoffman'], 'hoffman', text, target_mentions)
        target_mentions = self.check_target(['caleb jennings', 'calebjennings'], 'caleb_jennings', text, target_mentions)
        target_mentions = self.check_target(['savino'], 'savino', text, target_mentions)
        target_mentions = self.check_target(['david corn', 'davidcorn'], 'david_corn', text, target_mentions)
        target_mentions = self.check_target(['oreskes'], 'oreskes', text, target_mentions)
        target_mentions = self.check_target(['mendoza'], 'mendoza', text, target_mentions)
        target_mentions = self.check_target(['heatherton'], 'heatherton', text, target_mentions)
        target_mentions = self.check_target(['roy price', 'royprice'], 'roy_price', text, target_mentions)
        target_mentions = self.check_target(['sizemore'], 'sizemore', text, target_mentions)
        target_mentions = self.check_target(['tambor'], 'tambor', text, target_mentions)
        target_mentions = self.check_target(['westwick'], 'westwick', text, target_mentions)
        target_mentions = self.check_target(['von trier', 'vontrier', 'larsvontrier'], 'von_trier', text, target_mentions)
        target_mentions = self.check_target(['david marchant', 'davidmarchant'], 'david_marchant', text, target_mentions)
        target_mentions = self.check_target(["howie rubin", "howierubin"], "howie_rubin", text, target_mentions)
        target_mentions = self.check_target(['blaine'], 'blaine', text, target_mentions)
        target_mentions = self.check_target(['russell simmons', 'russellsimmons'], 'russell_simmons', text, target_mentions)
        target_mentions = self.check_target(['roy moore', 'roymoore'], 'moore', text, target_mentions)
        # for target_list in all_targets_list:
        #     self.check_target(['roy moore', 'roymoore'], target_list[0], text, target_mentions)
        return (target_mentions)

    def process_tweet_targets(self, tweet):
        body_target_mentions = None
        quoted_status_target_mentions = None
        RT_target_mentions = None
        gnip_url_title_mentions = None

        if tweet['body']:
            body_target_mentions = self.check_targets(tweet['body'])

        if tweet['quoted_status_body']:
            quoted_status_target_mentions = self.check_targets(tweet['quoted_status_body'])

        #     if tweet['RT_body']:
        #         RT_target_mentions = check_targets(tweet['RT_body'])

        if tweet['gnip_url_title']:
            try:
                gnip_url_title_mentions = [self.check_targets(i) for i in tweet['gnip_url_title']]
                gnip_url_title_mentions = list(set([i for j in gnip_url_title_mentions for i in j]))
            except:
                pass

        tweet['body_target_mentions'] = body_target_mentions
        tweet['quoted_status_target_mentions'] = quoted_status_target_mentions
        tweet['RT_target_mentions'] = RT_target_mentions
        tweet['gnip_url_title_mentions'] = gnip_url_title_mentions

        if body_target_mentions:
            tweet['body_target_mentions_validated'] = self.validate_name(tweet['body'],
                                                                    body_target_mentions,
                                                                    self.target_dic,
                                                                    self.target_last_names)

            if len(tweet['body_target_mentions_validated']) > 0:
                tweet['body_target_mentions_validated_true'] = True

        if quoted_status_target_mentions:
            tweet['quoted_status_target_mentions_validated'] = self.validate_name(tweet['quoted_status_body'],
                                                                             quoted_status_target_mentions,
                                                                             self.target_dic,
                                                                             self.target_last_names)

            if len(tweet['quoted_status_target_mentions_validated']) > 0:
                tweet['quoted_status_target_mentions_validated_true'] = True

        if gnip_url_title_mentions:
            gnip_url_title_mentions_validated = [self.validate_name(i,
                                                               gnip_url_title_mentions,
                                                               self.target_dic,
                                                               self.target_last_names) for i in tweet['gnip_url_title']]

            gnip_url_title_mentions_validated = list(set([i for j in gnip_url_title_mentions_validated for i in j]))

            tweet['gnip_url_title_mentions_validated'] = gnip_url_title_mentions_validated

            if len(tweet['gnip_url_title_mentions_validated']) > 0:
                tweet['gnip_url_title_mentions_validated_true'] = True

        return (tweet)

    def remove_urls(self, text):
        text = re.sub(r'(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b', '', text, flags=re.MULTILINE)
        return (text)

    def get_clean_text(self,x):

        clean_text = self.remove_urls(x).strip()

        clean_text_toks = []

        drop = True
        for tok in clean_text.split():

            if drop is True:
                if tok.startswith('@'):
                    pass

                else:
                    clean_text_toks.append(tok)
            
            if drop is False:
                clean_text_toks.append(tok)

        clean_text = ' '.join(clean_text_toks)
        return (clean_text)


    def add_tweet_or_quoted_tweet(self,tweet):
        tweet['modified_quote_tweet'] = True

        try:
            body_text = self.get_clean_text(tweet["full_text"])
            clean_tweet = f'<TWEET>: {body_text}'
        except:
            clean_tweet = '<TWEET>:'

        try:

            quoted_status_body_text = self.get_clean_text(tweet['quoted_status_body'])
            clean_tweet = f'{clean_tweet}\n\n<QUOTED TWEET>: {quoted_status_body_text}'

        except:
            pass

        #     try:

        #         gnip_url_titles_texts = [get_clean_text(i) for i in list(set(tweet['gnip_url_title']))]
        #         gnip_url_descriptions_texts = [get_clean_text(i) for i in list(set(tweet['gnip_url_description']))]

        #         for title, desc in zip(gnip_url_titles_texts, gnip_url_descriptions_texts):

        #             ratio = fuzz.ratio(title.lower(),body_text.lower())
        #             #print(ratio)
        #             if ratio > 85:
        #                  tweet['modified_quote_tweet'] = False

        #             clean_tweet = f'{clean_tweet}\n\n<URL TITLE>: {title}\n<URL DESCRIPTION>: {desc}'
        # #         clean_tweet = f'{clean_tweet}\n\n<URL TITLE>: {gnip_url_title_text}'

        #     except:
        #         pass

        tweet['clean_tweet'] = clean_tweet

        return (tweet)

    def unique(self, sequence):
        seen = set()
        return [x for x in sequence if not (x in seen or seen.add(x))]

    
    def mask_tweets(self, tweet):

        fix_bob = re.compile('bob weinstein|bobweinstein', re.IGNORECASE)

        # targ_counter = defaultdict(lambda:0)

        counter = 0

        # for i, d in enumerate(dat):

        clean_tweet = fix_bob.sub('bob', tweet['clean_tweet'])

        # print(d['clean_tweet'])
        targets = [tweet["target"]]
        try:
            targets = tweet['body_target_mentions']
        except:
            pass
        try:
            targets += tweet['quoted_status_target_mentions']

        except:
            pass

        try:
            targets += tweet['gnip_url_title_mentions']
        except:
            pass

        targets = self.unique(targets)
        initial_targ_counter = 0
        
        mask_map = {}
        #print(targets)
        targ_i = -1
        for targ_i, targ in enumerate(targets):

            cur_targ_split = targ.split('_')

            if 'weinstein' in cur_targ_split:
                if 'bob' in cur_targ_split:
                    cur_targ = 'bob_weinstein'
                else:
                    cur_targ = 'harvey_weinstein'

            else:
                cur_targ = cur_targ_split[-1]

            # targ_counter[cur_targ] +=1

            if cur_targ == 'metoo':
                continue

            # print(cur_targ == 'metoo')
            mask_map[f"<TARGET {targ_i + 1}>"] = self.target_gold_name[cur_targ]

            if initial_targ_counter == 0:

                tweet['clean_tweet_masked'] = self.targ_dic[cur_targ].sub(f"<TARGET {targ_i + 1}>", clean_tweet)
                initial_targ_counter = 1
            else:

                tweet['clean_tweet_masked'] = self.targ_dic[cur_targ].sub(f"<TARGET {targ_i + 1}>",
                                                                     tweet['clean_tweet_masked'])

        #         d['clean_tweet_masked'] = re.sub('')

        # tweet['clean_tweet_masked'] = tweet['clean_tweet_masked'].replace('<TARGET> <TARGET>', '<TARGET>')

        tweet['clean_targets_n'] = targ_i + 1

        counter += 1

        tweet['mask_map'] = mask_map

        # dat[i] = d

        #     if counter % 50000 == 0:
        #         print(counter)

        return (tweet)
    def simple_mask_tweets(self, tweet):
        
        tweet['clean_tweet_masked'] = self.all_targ_regex.sub("<TARGET>", tweet["clean_tweet"])
        return tweet

    def mask_targets_process(self, tweet):
    
        tweet = self.add_tweet_or_quoted_tweet(tweet)
#         tweet = self.mask_tweets(tweet)
        tweet = self.simple_mask_tweets(tweet)
        return (tweet)

    def mask_all_db(self):
        print("masking all DB")
        counter = 0

        # for document in tqdm(self.metoo_tweets.find({'is_RT': True,
        #                                    '$or': [{'body_target_mentions_validated_true': True},
        #                                            {'quoted_status_target_mentions_validated_true': True},
        #                                            {'gnip_url_title_mentions_validated_true': True},
        #                                            {'body_target_mentions_validated_true': True}],
        #                                    'lang_pred': 'en',
        #                                    'lang_pred_prob': {'$gte': .3}})):
        for document in tqdm(self.metoo_tweets.find()):
                
            document = self.mask_targets_process(document)

            self.update_tweet_in_db(document)



            # counter += 1
            #
            # if counter % 10000 == 0:
            #     print(counter)

    def add_target_mentions_to_db(self):
        print("adding target mentions to DB")
        counter = 0

        for document in tqdm(self.metoo_tweets.find({'is_RT': True})):
            #Todo: fix lang prediction
            # lang_pred = self.wtl.pred_prob(document['body'])
            lang_pred = [[]]
            if len(lang_pred[0]) > 0:

                document['lang_pred'] = lang_pred[0][0][0]
                document['lang_pred_prob'] = lang_pred[0][0][1]

            else:
                document['lang_pred'] = 'unknown'
                document['lang_pred_prob'] = 0

            document = self.process_tweet_targets(document)

            self.update_tweet_in_db(document)

            # counter += 1
            #
            # if counter % 10000 == 0:
            #     print(counter)


    def add_target_date_validation_to_db(self):
        print("adding target date check to db")
        for document in tqdm(self.metoo_tweets.find({'is_RT': True})):
                                           # '$or': [{'body_target_mentions_validated_true': True},
                                           #         {'quoted_status_target_mentions_validated_true': True}],
                                           # 'lang_pred': 'en',
                                           # 'lang_pred_prob': {'$gte': .3},
                                           # 'time_check': {'$exists': False}}):

            document = self.check_target_dates(document)

            if document is None:
                print("ERROR in add TARGET dates!")
                break

            self.update_tweet_in_db(document)

    def update_tweet_in_db(self, document):
        
        try:
            self.metoo_tweets.update_one(
                {'_id': document['_id']},
                {'$set': document}
            )

        except:
            self.get_new_client()
            self.metoo_tweets.update_one(
                {'_id': document['_id']},
                {'$set': document}
            )

# %%
all_targets_list = get_all_targ_list(targs)
len(all_targets_list)
# Out:
# bad nelly
# too long or too short dwayne_duron_marshall
# too long or too short lars_von_trier
# too long or too short neil_degrasse_tyson
# too long or too short steven_wilder_striegel
# 246

# %%
duplicate_list = ["marshall", "klein", "miller", "weinstein", "moore", "rubin", "jr", "johnson"]

# %%
data_dir = "../../data/"
files = os.listdir(data_dir)
jason_targets = []
for f in files:
    if f.endswith("db"):
        jason_targets.append(f.split(".")[0])
all_jason_targets = [[t, " ".join(t.split("_"))] for t in jason_targets]

tweetPrep = NewTweetPreprocessor(all_jason_targets, target_dic)
# Out:
# building target regex
# failed to build date for tj_miller
# failed to build date for Bush
# failed to build date for harold_ford_jr
# failed to build date for díaz
# failed to build date for jaeger
# failed to build date for balazs
# failed to build date for arnault
# failed to build date for ck
# failed to build date for oreilly
# failed to build date for alvarez
# failed to build date for ayers
# failed to build date for cárdenas
# failed to build date for roland_g_fryer_jr
# failed to build date for Sneed
# failed to build date for kelly
# failed to build date for domínguez
# failed to build date for kihuen
# failed to build date for jensen

# %%
tweetPrep.all_targ_regex
# Out:
# re.compile(r'steven wilder striegel|wilder|striegel|stevenwilderstriegel|erick guerrero|guerrero|erickguerrero|jesse lacey|lacey|jesselacey|kevin spacey|spacey|kevinspacey|cody wilson|wilson|codywilson|john kenneally|kenneally|johnkenneally|caleb jennings|jennings|calebjennings|tj miller|miller|tjmiller|morgan spurlock|spurlock|morganspurlock|oliver stone|stone|oliverstone|leonard lopate|lopate|leonardlopate|sean hannity|hannity|seanhannity|alex kozinski|kozinski|alexkozinski|heath evans|evans|heathevans|calvin smyre|smyre|calvinsmyre|william kelley|kelley|williamkelley|steve butts|butts|stevebutts|brett kavanaugh|kavanaugh|brettkavanaugh|barry lubin|lubin|barrylubin|charles schwertner|schwertner|charlesschwertner|andrea ramsey|ramsey|andrearamsey|john lasseter|lasseter|johnlasseter|richard dreyfuss|dreyfuss|richarddreyfuss|max ogden|ogden|maxogden|ron carlson|carlson|roncarlson|ron jeremy|jeremy|ronjeremy|dayan candappa|candappa|dayancandappa|tom frieden|frieden|tomfrieden|melanie martinez|martinez|melaniemartinez|morgan freeman|freeman|morganfreeman|george takei|takei|georgetakei|eric greitens|greitens|ericgreitens|wesley goodman|goodman|wesleygoodman|nick carter|carter|nickcarter|eric schneiderman|schneiderman|ericschneiderman|allison mack|mack|allisonmack|ameer vann|vann|ameervann|knight landesman|landesman|knightlandesman|andrew kreisberg|kreisberg|andrewkreisberg|richard devaul|devaul|richarddevaul|corey lewandowski|lewandowski|coreylewandowski|alec klein|klein|alecklein|matt dababneh|dababneh|mattdababneh|christian rodriguez|rodriguez|christianrodriguez|gary goddard|goddard|garygoddard|sean hutchison|hutchison|seanhutchison|nicholas nixon|nixon|nicholasnixon|steve lebsock|lebsock|stevelebsock|trent franks|franks|trentfranks|kaj larsen|larsen|kajlarsen|patrick meehan|meehan|patrickmeehan|james toback|toback|jamestoback|nelly|nelly|dwayne duron marshall|duron|marshall|dwayneduronmarshall|ryan lizza|lizza|ryanlizza|james levine|levine|jameslevine|chris savino|savino|chrissavino|michael oreskes|oreskes|michaeloreskes|glenn thrush|thrush|glennthrush|ben affleck|affleck|benaffleck|clay johnson|johnson|clayjohnson|brett ratner|ratner|brettratner|mohamed muqtar|muqtar|mohamedmuqtar|george hw Bush|Bush|georgehwBush|chase finlay|finlay|chasefinlay|patrick demarchelier|demarchelier|patrickdemarchelier|david marchant|marchant|davidmarchant|nick caporella|caporella|nickcaporella|corey coleman|coleman|coreycoleman|scott baio|baio|scottbaio|ed murray|murray|edmurray|burns strider|strider|burnsstrider|don hazen|hazen|donhazen|nick sauer|sauer|nicksauer|scott courtney|courtney|scottcourtney|dustin marshall|marshall|dustinmarshall|harold ford jr|ford|haroldfordjr|junot díaz|díaz|junotdíaz|blake farenthold|farenthold|blakefarenthold|jeffrey klein|klein|jeffreyklein|asia argento|argento|asiaargento|dustin hoffman|hoffman|dustinhoffman|avital ronell|ronell|avitalronell|murray miller|miller|murraymiller|michael hafford|hafford|michaelhafford|ed westwick|westwick|edwestwick|andre passos|passos|andrepassos|charlie walk|walk|charliewalk|albert schultz|schultz|albertschultz|wayne pacelle|pacelle|waynepacelle|ken baker|baker|kenbaker|charlie hallowell|hallowell|charliehallowell|donovan mcnabb|mcnabb|donovanmcnabb|kimberly guilfoyle|guilfoyle|kimberlyguilfoyle|matt lauer|lauer|mattlauer|hamilton fish|fish|hamiltonfish|steven seagal|seagal|stevenseagal|t florian jaeger|florian|jaeger|tflorianjaeger|robert reece|reece|robertreece|rhys james|james|rhysjames|matthew weiner|weiner|matthewweiner|michael ferro|ferro|michaelferro|sam isaly|isaly|samisaly|jeremy piven|piven|jeremypiven|shervin pishevar|pishevar|shervinpishevar|vincent cirrincione|cirrincione|vincentcirrincione|benton strong|strong|bentonstrong|paul shapiro|shapiro|paulshapiro|brad kern|kern|bradkern|tony mendoza|mendoza|tonymendoza|justin caldbeck|caldbeck|justincaldbeck|vince ingenito|ingenito|vinceingenito|roman polanski|polanski|romanpolanski|daniel zwerdling|zwerdling|danielzwerdling|m ...
# re.IGNORECASE|re.UNICODE)

# %%
tweetPrep.mask_all_db()
# Out:
# masking all DB
# 22603062it [12:06:02, 518.87it/s]

# %%
len(tweetPrep.targ_dic)
# Out:
# 263

# %%
all_targets_list
# Out:
# [['dustin_hoffman', 'dustin hoffman'],
#  ['knight_landesman', 'knight landesman'],
#  'nelly',
#  ['james_toback', 'james toback'],
#  ['steve_lebsock', 'steve lebsock'],
#  ['harvey_weinstein', 'harvey weinstein'],
#  ['al_franken', 'al franken'],
#  ['allison_mack', 'allison mack'],
#  ['andrea_ramsey', 'andrea ramsey'],
#  ['andy_rubin', 'andy rubin'],
#  ['asia_argento', 'asia argento'],
#  ['aziz_ansari', 'aziz ansari'],
#  ['ben_affleck', 'ben affleck'],
#  ['ben_vereen', 'ben vereen'],
#  ['bob_weinstein', 'bob weinstein'],
#  ['boyd_tinsley', 'boyd tinsley'],
#  ['brett_kavanaugh', 'brett kavanaugh'],
#  ['brett_ratner', 'brett ratner'],
#  ['bruce_weber', 'bruce weber'],
#  ['bryan_singer', 'bryan singer'],
#  ['charles_payne', 'charles payne'],
#  ['charlie_rose', 'charlie rose'],
#  ['chris_hardwick', 'chris hardwick'],
#  ['cody_wilson', 'cody wilson'],
#  ['corey_coleman', 'corey coleman'],
#  ['cristiano_ronaldo', 'cristiano ronaldo'],
#  ['cristina_garcia', 'cristina garcia'],
#  ['curtis_hill', 'curtis hill'],
#  ['daniel_zwerdling', 'daniel zwerdling'],
#  ['david_copperfield', 'david copperfield'],
#  ['demos_parneros', 'demos parneros'],
#  ['donald_trump', 'donald trump'],
#  ['ed_westwick', 'ed westwick'],
#  ['eric_bolling', 'eric bolling'],
#  ['eric_greitens', 'eric greitens'],
#  ['eric_schneiderman', 'eric schneiderman'],
#  ['garrison_keillor', 'garrison keillor'],
#  ['george_takei', 'george takei'],
#  ['gerard_depardieu', 'gerard depardieu'],
#  ['glenn_thrush', 'glenn thrush'],
#  ['hamilton_fish', 'hamilton fish'],
#  ['israel_horovitz', 'israel horovitz'],
#  ['james_franco', 'james franco'],
#  ['james_levine', 'james levine'],
#  ['james_rosen', 'james rosen'],
#  ['jeremy_piven', 'jeremy piven'],
#  ['jesse_lacey', 'jesse lacey'],
#  ['john_besh', 'john besh'],
#  ['john_conyers', 'john conyers'],
#  ['john_lasseter', 'john lasseter'],
#  ['jonathan_schwartz', 'jonathan schwartz'],
#  ['keith_raniere', 'keith raniere'],
#  ['ken_friedman', 'ken friedman'],
#  ['kevin_spacey', 'kevin spacey'],
#  ['leon_wieseltier', 'leon wieseltier'],
#  ['leonard_lopate', 'leonard lopate'],
#  ['les_moonves', 'les moonves'],
#  ['luc_besson', 'luc besson'],
#  ['mario_batali', 'mario batali'],
#  ['mario_testino', 'mario testino'],
#  ['mark_halperin', 'mark halperin'],
#  ['matt_dababneh', 'matt dababneh'],
#  ['matt_lauer', 'matt lauer'],
#  ['mel_watt', 'mel watt'],
#  ['michael_douglas', 'michael douglas'],
#  ['michael_feinberg', 'michael feinberg'],
#  ['michael_ferro', 'michael ferro'],
#  ['michael_oreskes', 'michael oreskes'],
#  ['morgan_freeman', 'morgan freeman'],
#  ['morgan_spurlock', 'morgan spurlock'],
#  ['patrick_meehan', 'patrick meehan'],
#  ['paul_haggis', 'paul haggis'],
#  ['peter_martins', 'peter martins'],
#  ['richard_dreyfuss', 'richard dreyfuss'],
#  ['roman_polanski', 'roman polanski'],
#  ['roy_moore', 'roy moore'],
#  ['ryan_lizza', 'ryan lizza'],
#  ['ryan_seacrest', 'ryan seacrest'],
#  ['scott_baio', 'scott baio'],
#  ['sherman_alexie', 'sherman alexie'],
#  ['steve_wynn', 'steve wynn'],
#  ['steven_seagal', 'steven seagal'],
#  ['tavis_smiley', 'tavis smiley'],
#  ['tom_brokaw', 'tom brokaw'],
#  ['tom_frieden', 'tom frieden'],
#  ['tom_sizemore', 'tom sizemore'],
#  ['trent_franks', 'trent franks'],
#  ['william_strampel', 'william strampel'],
#  ['adam_venit', 'adam venit'],
#  ['adrian_carrasquillo', 'adrian carrasquillo'],
#  ['albert_schultz', 'albert schultz'],
#  ['alec_klein', 'alec klein'],
#  ['alex_jones', 'alex jones'],
#  ['alex_kozinski', 'alex kozinski'],
#  ['ameer_vann', 'ameer vann'],
#  ['amit_singhal', 'amit singhal'],
#  ['andre_passos', 'andre passos'],
#  ['andrew_creighton', 'andrew creighton'],
#  ['andrew_kreisberg', 'andrew kreisberg'],
#  ['andy_dick', 'andy dick'],
#  ['andy_henry', 'andy henry'],
#  ['andy_savage', 'andy savage'],
#  ['antonin_kratochvil', 'antonin kratochvil'],
#  ['antonin_kratochvil (ext.)', 'antonin kratochvil (ext.)'],
#  ['avital_ronell', 'avital ronell'],
#  ['barry_lubin', 'barry lubin'],
#  ['benjamin_sparks', 'benjamin sparks'],
#  ['benton_strong', 'benton strong'],
#  ['bill_hybels', 'bill hybels'],
#  ['blake_farenthold', 'blake farenthold'],
#  ['bobby_scott', 'bobby scott'],
#  ['borris_miles', 'borris miles'],
#  ['brad_kern', 'brad kern'],
#  ['burns_strider', 'burns strider'],
#  ['caleb_jennings', 'caleb jennings'],
#  ['calvin_smyre', 'calvin smyre'],
#  ['carlos_uresti', 'carlos uresti'],
#  ['charles_schwertner', 'charles schwertner'],
#  ['charlie_hallowell', 'charlie hallowell'],
#  ['charlie_walk', 'charlie walk'],
#  ['chase_finlay', 'chase finlay'],
#  ['chris_sacca', 'chris sacca'],
#  ['chris_savino', 'chris savino'],
#  ['christian_rodriguez', 'christian rodriguez'],
#  ['clay_johnson', 'clay johnson'],
#  ['corey_lewandowski', 'corey lewandowski'],
#  ['dan_harmon', 'dan harmon'],
#  ['dan_johnson', 'dan johnson'],
#  ['daniel_handler', 'daniel handler'],
#  ['danny_masterson', 'danny masterson'],
#  ['dave_mcclure', 'dave mcclure'],
#  ['david_bellemere', 'david bellemere'],
#  ['david_blaine', 'david blaine'],
#  ['david_corn', 'david corn'],
#  ['david_keyes', 'david keyes'],
#  ['david_marchant', 'david marchant'],
#  ['dayan_candappa', 'dayan candappa'],
#  ['don_hazen', 'don hazen'],
#  ['donovan_mcnabb', 'donovan mcnabb'],
#  ['dustin_marshall', 'dustin marshall'],
#  ['dwayne_duron_marshall', 'dwayne duron marshall'],
#  ['dylan_howard', 'dylan howard'],
#  ['ed_crane', 'ed crane'],
#  ['ed_murray', 'ed murray'],
#  ['eddie_berganza', 'eddie berganza'],
#  ['eric_bauman', 'eric bauman'],
#  ['eric_weinberger', 'eric weinberger'],
#  ['erick_guerrero', 'erick guerrero'],
#  ['ethan_kath', 'ethan kath'],
#  ['francisco_ayala', 'francisco ayala'],
#  ['frankie_shaw', 'frankie shaw'],
#  ['gary_goddard', 'gary goddard'],
#  ['geoffrey_rush', 'geoffrey rush'],
#  ['george_tyndall', 'george tyndall'],
#  ['greg_kadel', 'greg kadel'],
#  ['hadrian_belove', 'hadrian belove'],
#  ['harry_knowles', 'harry knowles'],
#  ['heath_evans', 'heath evans'],
#  ['howie_rubin', 'howie rubin'],
#  ['ike_taylor', 'ike taylor'],
#  ['jann_wenner', 'jann wenner'],
#  ['jason_mojica', 'jason mojica'],
#  ['jeff_franklin', 'jeff franklin'],
#  ['jeff_kruse', 'jeff kruse'],
#  ['jeffrey_klein', 'jeffrey klein'],
#  ['jeffrey_tambor', 'jeffrey tambor'],
#  ['jeremy_tooker', 'jeremy tooker'],
#  ['joel_kramer', 'joel kramer'],
#  ['john_hockenberry', 'john hockenberry'],
#  ['john_kenneally', 'john kenneally'],
#  ['john_kricfalusi', 'john kricfalusi'],
#  ['jon_heely', 'jon heely'],
#  ['justin_caldbeck', 'justin caldbeck'],
#  ['kaj_larsen', 'kaj larsen'],
#  ['karl_templer', 'karl templer'],
#  ['ken_baker', 'ken baker'],
#  ['kevin_braun', 'kevin braun'],
#  ['kimberly_guilfoyle', 'kimberly guilfoyle'],
#  ['kirt_webster', 'kirt webster'],
#  ['larry_nassar', 'larry nassar'],
#  ['lars_von_trier', 'lars von trier'],
#  ['lawrence_krauss', 'lawrence krauss'],
#  ['lockhart_steele', 'lockhart steele'],
#  ['lorin_stein', 'lorin stein'],
#  ['mark_mellor', 'mark mellor'],
#  ['mark_schwahn', 'mark schwahn'],
#  ['marshall_faulk', 'marshall faulk'],
#  ['matt_zimmerman', 'matt zimmerman'],
#  ['matthew_weiner', 'matthew weiner'],
#  ['max_ogden', 'max ogden'],
#  ['melanie_martinez', 'melanie martinez'],
#  ['michael_hafford', 'michael hafford'],
#  ['michael_weatherly', 'michael weatherly'],
#  ['mike_germano', 'mike germano'],
#  ['mike_isabella', 'mike isabella'],
#  ['mohamed_muqtar', 'mohamed muqtar'],
#  ['murray_miller', 'murray miller'],
#  ['neil_degrasse_tyson', 'neil degrasse tyson'],
#  ['nicholas_kettle', 'nicholas kettle'],
#  ['nicholas_nixon', 'nicholas nixon'],
#  ['nick_caporella', 'nick caporella'],
#  ['nick_carter', 'nick carter'],
#  ['nick_sauer', 'nick sauer'],
#  ['oliver_stone', 'oliver stone'],
#  ['patrick_demarchelier', 'patrick demarchelier'],
#  ['patrick_witty', 'patrick witty'],
#  ['paul_marciano', 'paul marciano'],
#  ['paul_shapiro', 'paul shapiro'],
#  ['paul_whalen', 'paul whalen'],
#  ['philip_berk', 'philip berk'],
#  ['raul_bocanegra', 'raul bocanegra'],
#  ['rhys_james', 'rhys james'],
#  ['richard_devaul', 'richard devaul'],
#  ['rick_day', 'rick day'],
#  ['robert_knepper', 'robert knepper'],
#  ['robert_moore', 'robert moore'],
#  ['robert_reece', 'robert reece'],
#  ['robert_scoble', 'robert scoble'],
#  ['ron_carlson', 'ron carlson'],
#  ['ron_jeremy', 'ron jeremy'],
#  ['ross_levinsohn', 'ross levinsohn'],
#  ['roy_price', 'roy price'],
#  ['russell_simmons', 'russell simmons'],
#  ['sam_isaly', 'sam isaly'],
#  ['scott_courtney', 'scott courtney'],
#  ['sean_hannity', 'sean hannity'],
#  ['sean_hutchison', 'sean hutchison'],
#  ['seth_sabal', 'seth sabal'],
#  ['shadie_elnashai', 'shadie elnashai'],
#  ['shervin_pishevar', 'shervin pishevar'],
#  ['stan_lee', 'stan lee'],
#  ['steve_butts', 'steve butts'],
#  ['steven_wilder_striegel', 'steven wilder striegel'],
#  ['sylvester_stallone', 'sylvester stallone'],
#  ['terdema_ussery', 'terdema ussery'],
#  ['todd_heatherton', 'todd heatherton'],
#  ['tom_ashbrook', 'tom ashbrook'],
#  ['tony_mendoza', 'tony mendoza'],
#  ['travis_kalanick', 'travis kalanick'],
#  ['tyler_grasham', 'tyler grasham'],
#  ['vince_ingenito', 'vince ingenito'],
#  ['vincent_cirrincione', 'vincent cirrincione'],
#  ['wayne_pacelle', 'wayne pacelle'],
#  ['wesley_goodman', 'wesley goodman'],
#  ['william_jacoby', 'william jacoby'],
#  ['william_kelley', 'william kelley']]

# %%
underlined_all_targets = [t[0] for t in all_targets_list]
for target in jason_targets:
    if target in underlined_all_targets:
        print("matched ", target)
    else:
        print("----------------------------------")
        print("NO MATCH", target)
        print("----------------------------------")
# Out:
# matched  steven_wilder_striegel
# matched  erick_guerrero
# matched  jesse_lacey
# matched  kevin_spacey
# matched  cody_wilson
# matched  john_kenneally
# matched  caleb_jennings
# ----------------------------------
# NO MATCH tj_miller
# ----------------------------------
# matched  morgan_spurlock
# matched  oliver_stone
# matched  leonard_lopate
# matched  sean_hannity
# matched  alex_kozinski
# matched  heath_evans
# matched  calvin_smyre
# matched  william_kelley
# matched  steve_butts
# matched  brett_kavanaugh
# matched  barry_lubin
# matched  charles_schwertner
# matched  andrea_ramsey
# matched  john_lasseter
# matched  richard_dreyfuss
# matched  max_ogden
# matched  ron_carlson
# matched  ron_jeremy
# matched  dayan_candappa
# matched  tom_frieden
# matched  melanie_martinez
# matched  morgan_freeman
# matched  george_takei
# matched  eric_greitens
# matched  wesley_goodman
# matched  nick_carter
# matched  eric_schneiderman
# matched  allison_mack
# matched  ameer_vann
# matched  knight_landesman
# matched  andrew_kreisberg
# matched  richard_devaul
# matched  corey_lewandowski
# matched  alec_klein
# matched  matt_dababneh
# matched  christian_rodriguez
# matched  gary_goddard
# matched  sean_hutchison
# matched  nicholas_nixon
# matched  steve_lebsock
# matched  trent_franks
# matched  kaj_larsen
# matched  patrick_meehan
# matched  james_toback
# ----------------------------------
# NO MATCH nelly
# ----------------------------------
# matched  dwayne_duron_marshall
# matched  ryan_lizza
# matched  james_levine
# matched  chris_savino
# matched  michael_oreskes
# matched  glenn_thrush
# matched  ben_affleck
# matched  clay_johnson
# matched  brett_ratner
# matched  mohamed_muqtar
# ----------------------------------
# NO MATCH george_hw_Bush
# ----------------------------------
# matched  chase_finlay
# matched  patrick_demarchelier
# matched  david_marchant
# matched  nick_caporella
# matched  corey_coleman
# matched  scott_baio
# matched  ed_murray
# matched  burns_strider
# matched  don_hazen
# matched  nick_sauer
# matched  scott_courtney
# matched  dustin_marshall
# ----------------------------------
# NO MATCH harold_ford_jr
# ----------------------------------
# ----------------------------------
# NO MATCH junot_díaz
# ----------------------------------
# matched  blake_farenthold
# matched  jeffrey_klein
# matched  asia_argento
# matched  dustin_hoffman
# matched  avital_ronell
# matched  murray_miller
# matched  michael_hafford
# matched  ed_westwick
# matched  andre_passos
# matched  charlie_walk
# matched  albert_schultz
# matched  wayne_pacelle
# matched  ken_baker
# matched  charlie_hallowell
# matched  donovan_mcnabb
# matched  kimberly_guilfoyle
# matched  matt_lauer
# matched  hamilton_fish
# matched  steven_seagal
# ----------------------------------
# NO MATCH t_florian_jaeger
# ----------------------------------
# matched  robert_reece
# matched  rhys_james
# matched  matthew_weiner
# matched  michael_ferro
# matched  sam_isaly
# matched  jeremy_piven
# matched  shervin_pishevar
# matched  vincent_cirrincione
# matched  benton_strong
# matched  paul_shapiro
# matched  brad_kern
# matched  tony_mendoza
# matched  justin_caldbeck
# matched  vince_ingenito
# matched  roman_polanski
# matched  daniel_zwerdling
# matched  michael_feinberg
# matched  eric_bauman
# matched  eric_bolling
# matched  roy_price
# matched  gerard_depardieu
# matched  patrick_witty
# matched  benjamin_sparks
# matched  tavis_smiley
# matched  dan_harmon
# matched  francisco_ayala
# ----------------------------------
# NO MATCH andré_balazs
# ----------------------------------
# matched  lorin_stein
# matched  seth_sabal
# matched  andrew_creighton
# matched  david_corn
# matched  sherman_alexie
# matched  ross_levinsohn
# matched  james_franco
# matched  paul_whalen
# matched  john_hockenberry
# matched  amit_singhal
# ----------------------------------
# NO MATCH jean-claude_arnault
# ----------------------------------
# matched  william_strampel
# matched  karl_templer
# matched  bob_weinstein
# matched  mike_germano
# matched  jeff_franklin
# matched  charlie_rose
# matched  mark_schwahn
# matched  kevin_braun
# matched  jeremy_tooker
# matched  leon_wieseltier
# matched  travis_kalanick
# matched  cristina_garcia
# matched  sylvester_stallone
# matched  garrison_keillor
# matched  rick_day
# matched  david_blaine
# matched  bryan_singer
# matched  jonathan_schwartz
# matched  ken_friedman
# matched  kirt_webster
# matched  stan_lee
# matched  demos_parneros
# matched  david_keyes
# matched  greg_kadel
# matched  chris_hardwick
# matched  mark_mellor
# matched  mario_batali
# matched  danny_masterson
# matched  ed_crane
# matched  howie_rubin
# matched  cristiano_ronaldo
# matched  paul_haggis
# ----------------------------------
# NO MATCH louis_ck
# ----------------------------------
# matched  nicholas_kettle
# matched  william_jacoby
# matched  hadrian_belove
# matched  andy_dick
# matched  jeff_kruse
# matched  tyler_grasham
# ----------------------------------
# NO MATCH bill_oreilly
# ----------------------------------
# matched  dylan_howard
# matched  robert_moore
# matched  harvey_weinstein
# matched  michael_douglas
# matched  harry_knowles
# matched  donald_trump
# matched  larry_nassar
# matched  al_franken
# matched  david_bellemere
# matched  geoffrey_rush
# matched  james_rosen
# matched  mel_watt
# ----------------------------------
# NO MATCH albert_j_alvarez
# ----------------------------------
# matched  luc_besson
# matched  charles_payne
# matched  todd_heatherton
# ----------------------------------
# NO MATCH h_brandt_ayers
# ----------------------------------
# matched  john_besh
# matched  adam_venit
# matched  tom_ashbrook
# matched  paul_marciano
# matched  matt_zimmerman
# matched  andy_savage
# matched  terdema_ussery
# matched  ben_vereen
# matched  joel_kramer
# matched  david_copperfield
# matched  chris_sacca
# matched  roy_moore
# matched  lars_von_trier
# matched  carlos_uresti
# matched  john_kricfalusi
# matched  andy_rubin
# matched  philip_berk
# matched  antonin_kratochvil
# matched  marshall_faulk
# matched  mario_testino
# matched  adrian_carrasquillo
# matched  steve_wynn
# matched  tom_sizemore
# matched  jeffrey_tambor
# matched  john_conyers
# matched  bruce_weber
# matched  curtis_hill
# matched  neil_degrasse_tyson
# matched  dave_mcclure
# matched  bobby_scott
# ----------------------------------
# NO MATCH tony_cárdenas
# ----------------------------------
# ----------------------------------
# NO MATCH roland_g_fryer_jr
# ----------------------------------
# ----------------------------------
# NO MATCH Earl_K_Sneed
# ----------------------------------
# matched  eddie_berganza
# matched  ike_taylor
# matched  jon_heely
# matched  shadie_elnashai
# matched  robert_scoble
# matched  jann_wenner
# matched  aziz_ansari
# matched  daniel_handler
# matched  les_moonves
# matched  lawrence_krauss
# matched  eric_weinberger
# matched  peter_martins
# matched  israel_horovitz
# matched  borris_miles
# matched  alex_jones
# matched  michael_weatherly
# matched  andy_henry
# matched  bill_hybels
# matched  dan_johnson
# ----------------------------------
# NO MATCH robert_r_kelly
# ----------------------------------
# matched  ryan_seacrest
# matched  mark_halperin
# ----------------------------------
# NO MATCH jorge_domínguez
# ----------------------------------
# ----------------------------------
# NO MATCH rubén_kihuen
# ----------------------------------
# matched  tom_brokaw
# matched  keith_raniere
# matched  lockhart_steele
# matched  raul_bocanegra
# matched  jason_mojica
# ----------------------------------
# NO MATCH peter_aalbæk_jensen
# ----------------------------------
# matched  russell_simmons
# matched  boyd_tinsley
# matched  ethan_kath
# matched  mike_isabella
# matched  robert_knepper
# matched  george_tyndall

# %%
all_targets_list
# Out:
# [['dustin_hoffman', 'dustin hoffman'],
#  ['knight_landesman', 'knight landesman'],
#  'nelly',
#  ['james_toback', 'james toback'],
#  ['steve_lebsock', 'steve lebsock'],
#  ['harvey_weinstein', 'harvey weinstein'],
#  ['al_franken', 'al franken'],
#  ['allison_mack', 'allison mack'],
#  ['andrea_ramsey', 'andrea ramsey'],
#  ['andy_rubin', 'andy rubin'],
#  ['asia_argento', 'asia argento'],
#  ['aziz_ansari', 'aziz ansari'],
#  ['ben_affleck', 'ben affleck'],
#  ['ben_vereen', 'ben vereen'],
#  ['bob_weinstein', 'bob weinstein'],
#  ['boyd_tinsley', 'boyd tinsley'],
#  ['brett_kavanaugh', 'brett kavanaugh'],
#  ['brett_ratner', 'brett ratner'],
#  ['bruce_weber', 'bruce weber'],
#  ['bryan_singer', 'bryan singer'],
#  ['charles_payne', 'charles payne'],
#  ['charlie_rose', 'charlie rose'],
#  ['chris_hardwick', 'chris hardwick'],
#  ['cody_wilson', 'cody wilson'],
#  ['corey_coleman', 'corey coleman'],
#  ['cristiano_ronaldo', 'cristiano ronaldo'],
#  ['cristina_garcia', 'cristina garcia'],
#  ['curtis_hill', 'curtis hill'],
#  ['daniel_zwerdling', 'daniel zwerdling'],
#  ['david_copperfield', 'david copperfield'],
#  ['demos_parneros', 'demos parneros'],
#  ['donald_trump', 'donald trump'],
#  ['ed_westwick', 'ed westwick'],
#  ['eric_bolling', 'eric bolling'],
#  ['eric_greitens', 'eric greitens'],
#  ['eric_schneiderman', 'eric schneiderman'],
#  ['garrison_keillor', 'garrison keillor'],
#  ['george_takei', 'george takei'],
#  ['gerard_depardieu', 'gerard depardieu'],
#  ['glenn_thrush', 'glenn thrush'],
#  ['hamilton_fish', 'hamilton fish'],
#  ['israel_horovitz', 'israel horovitz'],
#  ['james_franco', 'james franco'],
#  ['james_levine', 'james levine'],
#  ['james_rosen', 'james rosen'],
#  ['jeremy_piven', 'jeremy piven'],
#  ['jesse_lacey', 'jesse lacey'],
#  ['john_besh', 'john besh'],
#  ['john_conyers', 'john conyers'],
#  ['john_lasseter', 'john lasseter'],
#  ['jonathan_schwartz', 'jonathan schwartz'],
#  ['keith_raniere', 'keith raniere'],
#  ['ken_friedman', 'ken friedman'],
#  ['kevin_spacey', 'kevin spacey'],
#  ['leon_wieseltier', 'leon wieseltier'],
#  ['leonard_lopate', 'leonard lopate'],
#  ['les_moonves', 'les moonves'],
#  ['luc_besson', 'luc besson'],
#  ['mario_batali', 'mario batali'],
#  ['mario_testino', 'mario testino'],
#  ['mark_halperin', 'mark halperin'],
#  ['matt_dababneh', 'matt dababneh'],
#  ['matt_lauer', 'matt lauer'],
#  ['mel_watt', 'mel watt'],
#  ['michael_douglas', 'michael douglas'],
#  ['michael_feinberg', 'michael feinberg'],
#  ['michael_ferro', 'michael ferro'],
#  ['michael_oreskes', 'michael oreskes'],
#  ['morgan_freeman', 'morgan freeman'],
#  ['morgan_spurlock', 'morgan spurlock'],
#  ['patrick_meehan', 'patrick meehan'],
#  ['paul_haggis', 'paul haggis'],
#  ['peter_martins', 'peter martins'],
#  ['richard_dreyfuss', 'richard dreyfuss'],
#  ['roman_polanski', 'roman polanski'],
#  ['roy_moore', 'roy moore'],
#  ['ryan_lizza', 'ryan lizza'],
#  ['ryan_seacrest', 'ryan seacrest'],
#  ['scott_baio', 'scott baio'],
#  ['sherman_alexie', 'sherman alexie'],
#  ['steve_wynn', 'steve wynn'],
#  ['steven_seagal', 'steven seagal'],
#  ['tavis_smiley', 'tavis smiley'],
#  ['tom_brokaw', 'tom brokaw'],
#  ['tom_frieden', 'tom frieden'],
#  ['tom_sizemore', 'tom sizemore'],
#  ['trent_franks', 'trent franks'],
#  ['william_strampel', 'william strampel'],
#  ['adam_venit', 'adam venit'],
#  ['adrian_carrasquillo', 'adrian carrasquillo'],
#  ['albert_schultz', 'albert schultz'],
#  ['alec_klein', 'alec klein'],
#  ['alex_jones', 'alex jones'],
#  ['alex_kozinski', 'alex kozinski'],
#  ['ameer_vann', 'ameer vann'],
#  ['amit_singhal', 'amit singhal'],
#  ['andre_passos', 'andre passos'],
#  ['andrew_creighton', 'andrew creighton'],
#  ['andrew_kreisberg', 'andrew kreisberg'],
#  ['andy_dick', 'andy dick'],
#  ['andy_henry', 'andy henry'],
#  ['andy_savage', 'andy savage'],
#  ['antonin_kratochvil', 'antonin kratochvil'],
#  ['antonin_kratochvil (ext.)', 'antonin kratochvil (ext.)'],
#  ['avital_ronell', 'avital ronell'],
#  ['barry_lubin', 'barry lubin'],
#  ['benjamin_sparks', 'benjamin sparks'],
#  ['benton_strong', 'benton strong'],
#  ['bill_hybels', 'bill hybels'],
#  ['blake_farenthold', 'blake farenthold'],
#  ['bobby_scott', 'bobby scott'],
#  ['borris_miles', 'borris miles'],
#  ['brad_kern', 'brad kern'],
#  ['burns_strider', 'burns strider'],
#  ['caleb_jennings', 'caleb jennings'],
#  ['calvin_smyre', 'calvin smyre'],
#  ['carlos_uresti', 'carlos uresti'],
#  ['charles_schwertner', 'charles schwertner'],
#  ['charlie_hallowell', 'charlie hallowell'],
#  ['charlie_walk', 'charlie walk'],
#  ['chase_finlay', 'chase finlay'],
#  ['chris_sacca', 'chris sacca'],
#  ['chris_savino', 'chris savino'],
#  ['christian_rodriguez', 'christian rodriguez'],
#  ['clay_johnson', 'clay johnson'],
#  ['corey_lewandowski', 'corey lewandowski'],
#  ['dan_harmon', 'dan harmon'],
#  ['dan_johnson', 'dan johnson'],
#  ['daniel_handler', 'daniel handler'],
#  ['danny_masterson', 'danny masterson'],
#  ['dave_mcclure', 'dave mcclure'],
#  ['david_bellemere', 'david bellemere'],
#  ['david_blaine', 'david blaine'],
#  ['david_corn', 'david corn'],
#  ['david_keyes', 'david keyes'],
#  ['david_marchant', 'david marchant'],
#  ['dayan_candappa', 'dayan candappa'],
#  ['don_hazen', 'don hazen'],
#  ['donovan_mcnabb', 'donovan mcnabb'],
#  ['dustin_marshall', 'dustin marshall'],
#  ['dwayne_duron_marshall', 'dwayne duron marshall'],
#  ['dylan_howard', 'dylan howard'],
#  ['ed_crane', 'ed crane'],
#  ['ed_murray', 'ed murray'],
#  ['eddie_berganza', 'eddie berganza'],
#  ['eric_bauman', 'eric bauman'],
#  ['eric_weinberger', 'eric weinberger'],
#  ['erick_guerrero', 'erick guerrero'],
#  ['ethan_kath', 'ethan kath'],
#  ['francisco_ayala', 'francisco ayala'],
#  ['frankie_shaw', 'frankie shaw'],
#  ['gary_goddard', 'gary goddard'],
#  ['geoffrey_rush', 'geoffrey rush'],
#  ['george_tyndall', 'george tyndall'],
#  ['greg_kadel', 'greg kadel'],
#  ['hadrian_belove', 'hadrian belove'],
#  ['harry_knowles', 'harry knowles'],
#  ['heath_evans', 'heath evans'],
#  ['howie_rubin', 'howie rubin'],
#  ['ike_taylor', 'ike taylor'],
#  ['jann_wenner', 'jann wenner'],
#  ['jason_mojica', 'jason mojica'],
#  ['jeff_franklin', 'jeff franklin'],
#  ['jeff_kruse', 'jeff kruse'],
#  ['jeffrey_klein', 'jeffrey klein'],
#  ['jeffrey_tambor', 'jeffrey tambor'],
#  ['jeremy_tooker', 'jeremy tooker'],
#  ['joel_kramer', 'joel kramer'],
#  ['john_hockenberry', 'john hockenberry'],
#  ['john_kenneally', 'john kenneally'],
#  ['john_kricfalusi', 'john kricfalusi'],
#  ['jon_heely', 'jon heely'],
#  ['justin_caldbeck', 'justin caldbeck'],
#  ['kaj_larsen', 'kaj larsen'],
#  ['karl_templer', 'karl templer'],
#  ['ken_baker', 'ken baker'],
#  ['kevin_braun', 'kevin braun'],
#  ['kimberly_guilfoyle', 'kimberly guilfoyle'],
#  ['kirt_webster', 'kirt webster'],
#  ['larry_nassar', 'larry nassar'],
#  ['lars_von_trier', 'lars von trier'],
#  ['lawrence_krauss', 'lawrence krauss'],
#  ['lockhart_steele', 'lockhart steele'],
#  ['lorin_stein', 'lorin stein'],
#  ['mark_mellor', 'mark mellor'],
#  ['mark_schwahn', 'mark schwahn'],
#  ['marshall_faulk', 'marshall faulk'],
#  ['matt_zimmerman', 'matt zimmerman'],
#  ['matthew_weiner', 'matthew weiner'],
#  ['max_ogden', 'max ogden'],
#  ['melanie_martinez', 'melanie martinez'],
#  ['michael_hafford', 'michael hafford'],
#  ['michael_weatherly', 'michael weatherly'],
#  ['mike_germano', 'mike germano'],
#  ['mike_isabella', 'mike isabella'],
#  ['mohamed_muqtar', 'mohamed muqtar'],
#  ['murray_miller', 'murray miller'],
#  ['neil_degrasse_tyson', 'neil degrasse tyson'],
#  ['nicholas_kettle', 'nicholas kettle'],
#  ['nicholas_nixon', 'nicholas nixon'],
#  ['nick_caporella', 'nick caporella'],
#  ['nick_carter', 'nick carter'],
#  ['nick_sauer', 'nick sauer'],
#  ['oliver_stone', 'oliver stone'],
#  ['patrick_demarchelier', 'patrick demarchelier'],
#  ['patrick_witty', 'patrick witty'],
#  ['paul_marciano', 'paul marciano'],
#  ['paul_shapiro', 'paul shapiro'],
#  ['paul_whalen', 'paul whalen'],
#  ['philip_berk', 'philip berk'],
#  ['raul_bocanegra', 'raul bocanegra'],
#  ['rhys_james', 'rhys james'],
#  ['richard_devaul', 'richard devaul'],
#  ['rick_day', 'rick day'],
#  ['robert_knepper', 'robert knepper'],
#  ['robert_moore', 'robert moore'],
#  ['robert_reece', 'robert reece'],
#  ['robert_scoble', 'robert scoble'],
#  ['ron_carlson', 'ron carlson'],
#  ['ron_jeremy', 'ron jeremy'],
#  ['ross_levinsohn', 'ross levinsohn'],
#  ['roy_price', 'roy price'],
#  ['russell_simmons', 'russell simmons'],
#  ['sam_isaly', 'sam isaly'],
#  ['scott_courtney', 'scott courtney'],
#  ['sean_hannity', 'sean hannity'],
#  ['sean_hutchison', 'sean hutchison'],
#  ['seth_sabal', 'seth sabal'],
#  ['shadie_elnashai', 'shadie elnashai'],
#  ['shervin_pishevar', 'shervin pishevar'],
#  ['stan_lee', 'stan lee'],
#  ['steve_butts', 'steve butts'],
#  ['steven_wilder_striegel', 'steven wilder striegel'],
#  ['sylvester_stallone', 'sylvester stallone'],
#  ['terdema_ussery', 'terdema ussery'],
#  ['todd_heatherton', 'todd heatherton'],
#  ['tom_ashbrook', 'tom ashbrook'],
#  ['tony_mendoza', 'tony mendoza'],
#  ['travis_kalanick', 'travis kalanick'],
#  ['tyler_grasham', 'tyler grasham'],
#  ['vince_ingenito', 'vince ingenito'],
#  ['vincent_cirrincione', 'vincent cirrincione'],
#  ['wayne_pacelle', 'wayne pacelle'],
#  ['wesley_goodman', 'wesley goodman'],
#  ['william_jacoby', 'william jacoby'],
#  ['william_kelley', 'william kelley']]

# %%
# Out:
# masking all DB
# 7160942it [1:34:04, 1268.60it/s]
# -------------------------------------------------
# KeyError        Traceback (most recent call last)
# <ipython-input-53-3244da28e34d> in <module>
# ----> 1 tweetPrep.mask_all_db()
#
# <ipython-input-51-095799030897> in mask_all_db(self)
#     649         for document in tqdm(self.metoo_tweets.find()):
#     650
# --> 651             document = self.mask_targets_process(document)
#     652
#     653             self.update_tweet_in_db(document)
#
# <ipython-input-51-095799030897> in mask_targets_process(self, tweet)
#     633     def mask_targets_process(self, tweet):
#     634         tweet = self.add_tweet_or_quoted_tweet(tweet)
# --> 635         tweet = self.mask_tweets(tweet)
#     636         return (tweet)
#     637
#
# <ipython-input-51-095799030897> in mask_tweets(self, tweet)
#     603
#     604             # print(cur_targ == 'metoo')
# --> 605             mask_map[f"<TARGET {targ_i + 1}>"] = self.target_gold_name[cur_targ]
#     606
#     607             if initial_targ_counter == 0:
#
# KeyError: 'Bush'

# %%
tweetPrep.targ_dic
# Out:
# {'hoffman': re.compile(r'dustin hoffman|hoffman|dustinhoffman',
#  re.IGNORECASE|re.UNICODE),
#  'landesman': re.compile(r'knight landesman|landesman|knightlandesman',
#  re.IGNORECASE|re.UNICODE),
#  'nelly': re.compile(r'nelly|nelly', re.IGNORECASE|re.UNICODE),
#  'toback': re.compile(r'james toback|toback|jamestoback',
#  re.IGNORECASE|re.UNICODE),
#  'lebsock': re.compile(r'steve lebsock|lebsock|stevelebsock',
#  re.IGNORECASE|re.UNICODE),
#  'harvey_weinstein': re.compile(r'harvey weinstein|weinstein|harveyweinstein',
#  re.IGNORECASE|re.UNICODE),
#  'franken': re.compile(r'al franken|franken|alfranken',
#  re.IGNORECASE|re.UNICODE),
#  'mack': re.compile(r'allison mack|mack|allisonmack',
#  re.IGNORECASE|re.UNICODE),
#  'ramsey': re.compile(r'andrea ramsey|ramsey|andrearamsey',
#  re.IGNORECASE|re.UNICODE),
#  'rubin': re.compile(r'howie rubin|rubin|howierubin',
#  re.IGNORECASE|re.UNICODE),
#  'argento': re.compile(r'asia argento|argento|asiaargento',
#  re.IGNORECASE|re.UNICODE),
#  'ansari': re.compile(r'aziz ansari|ansari|azizansari',
#  re.IGNORECASE|re.UNICODE),
#  'affleck': re.compile(r'ben affleck|affleck|benaffleck',
#  re.IGNORECASE|re.UNICODE),
#  'vereen': re.compile(r'ben vereen|vereen|benvereen',
#  re.IGNORECASE|re.UNICODE),
#  'bob_weinstein': re.compile(r'bob weinstein|weinstein|bobweinstein',
#  re.IGNORECASE|re.UNICODE),
#  'tinsley': re.compile(r'boyd tinsley|tinsley|boydtinsley',
#  re.IGNORECASE|re.UNICODE),
#  'kavanaugh': re.compile(r'brett kavanaugh|kavanaugh|brettkavanaugh',
#  re.IGNORECASE|re.UNICODE),
#  'ratner': re.compile(r'brett ratner|ratner|brettratner',
#  re.IGNORECASE|re.UNICODE),
#  'weber': re.compile(r'bruce weber|weber|bruceweber',
#  re.IGNORECASE|re.UNICODE),
#  'singer': re.compile(r'bryan singer|singer|bryansinger',
#  re.IGNORECASE|re.UNICODE),
#  'payne': re.compile(r'charles payne|payne|charlespayne',
#  re.IGNORECASE|re.UNICODE),
#  'rose': re.compile(r'charlie rose|rose|charlierose',
#  re.IGNORECASE|re.UNICODE),
#  'hardwick': re.compile(r'chris hardwick|hardwick|chrishardwick',
#  re.IGNORECASE|re.UNICODE),
#  'wilson': re.compile(r'cody wilson|wilson|codywilson',
#  re.IGNORECASE|re.UNICODE),
#  'coleman': re.compile(r'corey coleman|coleman|coreycoleman',
#  re.IGNORECASE|re.UNICODE),
#  'ronaldo': re.compile(r'cristiano ronaldo|ronaldo|cristianoronaldo',
#  re.IGNORECASE|re.UNICODE),
#  'garcia': re.compile(r'cristina garcia|garcia|cristinagarcia',
#  re.IGNORECASE|re.UNICODE),
#  'hill': re.compile(r'curtis hill|hill|curtishill', re.IGNORECASE|re.UNICODE),
#  'zwerdling': re.compile(r'daniel zwerdling|zwerdling|danielzwerdling',
#  re.IGNORECASE|re.UNICODE),
#  'copperfield': re.compile(r'david copperfield|copperfield|davidcopperfield',
#  re.IGNORECASE|re.UNICODE),
#  'parneros': re.compile(r'demos parneros|parneros|demosparneros',
#  re.IGNORECASE|re.UNICODE),
#  'trump': re.compile(r'donald trump|trump|donaldtrump',
#  re.IGNORECASE|re.UNICODE),
#  'westwick': re.compile(r'ed westwick|westwick|edwestwick',
#  re.IGNORECASE|re.UNICODE),
#  'bolling': re.compile(r'eric bolling|bolling|ericbolling',
#  re.IGNORECASE|re.UNICODE),
#  'greitens': re.compile(r'eric greitens|greitens|ericgreitens',
#  re.IGNORECASE|re.UNICODE),
#  'schneiderman': re.compile(r'eric schneiderman|schneiderman|ericschneiderman',
#  re.IGNORECASE|re.UNICODE),
#  'keillor': re.compile(r'garrison keillor|keillor|garrisonkeillor',
#  re.IGNORECASE|re.UNICODE),
#  'takei': re.compile(r'george takei|takei|georgetakei',
#  re.IGNORECASE|re.UNICODE),
#  'depardieu': re.compile(r'gerard depardieu|depardieu|gerarddepardieu',
#  re.IGNORECASE|re.UNICODE),
#  'thrush': re.compile(r'glenn thrush|thrush|glennthrush',
#  re.IGNORECASE|re.UNICODE),
#  'fish': re.compile(r'hamilton fish|fish|hamiltonfish',
#  re.IGNORECASE|re.UNICODE),
#  'horovitz': re.compile(r'israel horovitz|horovitz|israelhorovitz',
#  re.IGNORECASE|re.UNICODE),
#  'franco': re.compile(r'james franco|franco|jamesfranco',
#  re.IGNORECASE|re.UNICODE),
#  'levine': re.compile(r'james levine|levine|jameslevine',
#  re.IGNORECASE|re.UNICODE),
#  'rosen': re.compile(r'james rosen|rosen|jamesrosen',
#  re.IGNORECASE|re.UNICODE),
#  'piven': re.compile(r'jeremy piven|piven|jeremypiven',
#  re.IGNORECASE|re.UNICODE),
#  'lacey': re.compile(r'jesse lacey|lacey|jesselacey',
#  re.IGNORECASE|re.UNICODE),
#  'besh': re.compile(r'john besh|besh|johnbesh', re.IGNORECASE|re.UNICODE),
#  'conyers': re.compile(r'john conyers|conyers|johnconyers',
#  re.IGNORECASE|re.UNICODE),
#  'lasseter': re.compile(r'john lasseter|lasseter|johnlasseter',
#  re.IGNORECASE|re.UNICODE),
#  'schwartz': re.compile(r'jonathan schwartz|schwartz|jonathanschwartz',
#  re.IGNORECASE|re.UNICODE),
#  'raniere': re.compile(r'keith raniere|raniere|keithraniere',
#  re.IGNORECASE|re.UNICODE),
#  'friedman': re.compile(r'ken friedman|friedman|kenfriedman',
#  re.IGNORECASE|re.UNICODE),
#  'spacey': re.compile(r'kevin spacey|spacey|kevinspacey',
#  re.IGNORECASE|re.UNICODE),
#  'wieseltier': re.compile(r'leon wieseltier|wieseltier|leonwieseltier',
#  re.IGNORECASE|re.UNICODE),
#  'lopate': re.compile(r'leonard lopate|lopate|leonardlopate',
#  re.IGNORECASE|re.UNICODE),
#  'moonves': re.compile(r'les moonves|moonves|lesmoonves',
#  re.IGNORECASE|re.UNICODE),
#  'besson': re.compile(r'luc besson|besson|lucbesson',
#  re.IGNORECASE|re.UNICODE),
#  'batali': re.compile(r'mario batali|batali|mariobatali',
#  re.IGNORECASE|re.UNICODE),
#  'testino': re.compile(r'mario testino|testino|mariotestino',
#  re.IGNORECASE|re.UNICODE),
#  'halperin': re.compile(r'mark halperin|halperin|markhalperin',
#  re.IGNORECASE|re.UNICODE),
#  'dababneh': re.compile(r'matt dababneh|dababneh|mattdababneh',
#  re.IGNORECASE|re.UNICODE),
#  'lauer': re.compile(r'matt lauer|lauer|mattlauer', re.IGNORECASE|re.UNICODE),
#  'watt': re.compile(r'mel watt|watt|melwatt', re.IGNORECASE|re.UNICODE),
#  'douglas': re.compile(r'michael douglas|douglas|michaeldouglas',
#  re.IGNORECASE|re.UNICODE),
#  'feinberg': re.compile(r'michael feinberg|feinberg|michaelfeinberg',
#  re.IGNORECASE|re.UNICODE),
#  'ferro': re.compile(r'michael ferro|ferro|michaelferro',
#  re.IGNORECASE|re.UNICODE),
#  'oreskes': re.compile(r'michael oreskes|oreskes|michaeloreskes',
#  re.IGNORECASE|re.UNICODE),
#  'freeman': re.compile(r'morgan freeman|freeman|morganfreeman',
#  re.IGNORECASE|re.UNICODE),
#  'spurlock': re.compile(r'morgan spurlock|spurlock|morganspurlock',
#  re.IGNORECASE|re.UNICODE),
#  'meehan': re.compile(r'patrick meehan|meehan|patrickmeehan',
#  re.IGNORECASE|re.UNICODE),
#  'haggis': re.compile(r'paul haggis|haggis|paulhaggis',
#  re.IGNORECASE|re.UNICODE),
#  'martins': re.compile(r'peter martins|martins|petermartins',
#  re.IGNORECASE|re.UNICODE),
#  'dreyfuss': re.compile(r'richard dreyfuss|dreyfuss|richarddreyfuss',
#  re.IGNORECASE|re.UNICODE),
#  'polanski': re.compile(r'roman polanski|polanski|romanpolanski',
#  re.IGNORECASE|re.UNICODE),
#  'moore': re.compile(r'roy moore|roymoore|moore', re.IGNORECASE|re.UNICODE),
#  'lizza': re.compile(r'ryan lizza|lizza|ryanlizza', re.IGNORECASE|re.UNICODE),
#  'seacrest': re.compile(r'ryan seacrest|seacrest|ryanseacrest',
#  re.IGNORECASE|re.UNICODE),
#  'baio': re.compile(r'scott baio|baio|scottbaio', re.IGNORECASE|re.UNICODE),
#  'alexie': re.compile(r'sherman alexie|alexie|shermanalexie',
#  re.IGNORECASE|re.UNICODE),
#  'wynn': re.compile(r'steve wynn|wynn|stevewynn', re.IGNORECASE|re.UNICODE),
#  'seagal': re.compile(r'steven seagal|seagal|stevenseagal',
#  re.IGNORECASE|re.UNICODE),
#  'smiley': re.compile(r'tavis smiley|smiley|tavissmiley',
#  re.IGNORECASE|re.UNICODE),
#  'brokaw': re.compile(r'tom brokaw|brokaw|tombrokaw',
#  re.IGNORECASE|re.UNICODE),
#  'frieden': re.compile(r'tom frieden|frieden|tomfrieden',
#  re.IGNORECASE|re.UNICODE),
#  'sizemore': re.compile(r'tom sizemore|sizemore|tomsizemore',
#  re.IGNORECASE|re.UNICODE),
#  'franks': re.compile(r'trent franks|franks|trentfranks',
#  re.IGNORECASE|re.UNICODE),
#  'strampel': re.compile(r'william strampel|strampel|williamstrampel',
#  re.IGNORECASE|re.UNICODE),
#  'venit': re.compile(r'adam venit|venit|adamvenit', re.IGNORECASE|re.UNICODE),
#  'carrasquillo': re.compile(r'adrian carrasquillo|carrasquillo|adriancarrasquillo',
#  re.IGNORECASE|re.UNICODE),
#  'schultz': re.compile(r'albert schultz|schultz|albertschultz',
#  re.IGNORECASE|re.UNICODE),
#  'klein': re.compile(r'jeffrey klein|klein|jeffreyklein',
#  re.IGNORECASE|re.UNICODE),
#  'jones': re.compile(r'alex jones|jones|alexjones', re.IGNORECASE|re.UNICODE),
#  'kozinski': re.compile(r'alex kozinski|kozinski|alexkozinski',
#  re.IGNORECASE|re.UNICODE),
#  'vann': re.compile(r'ameer vann|vann|ameervann', re.IGNORECASE|re.UNICODE),
#  'singhal': re.compile(r'amit singhal|singhal|amitsinghal',
#  re.IGNORECASE|re.UNICODE),
#  'passos': re.compile(r'andre passos|passos|andrepassos',
#  re.IGNORECASE|re.UNICODE),
#  'creighton': re.compile(r'andrew creighton|creighton|andrewcreighton',
#  re.IGNORECASE|re.UNICODE),
#  'kreisberg': re.compile(r'andrew kreisberg|kreisberg|andrewkreisberg',
#  re.IGNORECASE|re.UNICODE),
#  'dick': re.compile(r'andy dick|dick|andydick', re.IGNORECASE|re.UNICODE),
#  'henry': re.compile(r'andy henry|henry|andyhenry', re.IGNORECASE|re.UNICODE),
#  'savage': re.compile(r'andy savage|savage|andysavage',
#  re.IGNORECASE|re.UNICODE),
#  'kratochvil': re.compile(r'antonin kratochvil|kratochvil|antoninkratochvil',
#  re.IGNORECASE|re.UNICODE),
#  'kratochvil (ext.)': re.compile(r'antonin kratochvil (ext.)|kratochvil (ext.)|antoninkratochvil (ext.)',
#  re.IGNORECASE|re.UNICODE),
#  'ronell': re.compile(r'avital ronell|ronell|avitalronell',
#  re.IGNORECASE|re.UNICODE),
#  'lubin': re.compile(r'barry lubin|lubin|barrylubin',
#  re.IGNORECASE|re.UNICODE),
#  'sparks': re.compile(r'benjamin sparks|sparks|benjaminsparks',
#  re.IGNORECASE|re.UNICODE),
#  'strong': re.compile(r'benton strong|strong|bentonstrong',
#  re.IGNORECASE|re.UNICODE),
#  'hybels': re.compile(r'bill hybels|hybels|billhybels',
#  re.IGNORECASE|re.UNICODE),
#  'farenthold': re.compile(r'blake farenthold|farenthold|blakefarenthold',
#  re.IGNORECASE|re.UNICODE),
#  'scott': re.compile(r'bobby scott|scott|bobbyscott',
#  re.IGNORECASE|re.UNICODE),
#  'miles': re.compile(r'borris miles|miles|borrismiles',
#  re.IGNORECASE|re.UNICODE),
#  'kern': re.compile(r'brad kern|kern|bradkern', re.IGNORECASE|re.UNICODE),
#  'strider': re.compile(r'burns strider|strider|burnsstrider',
#  re.IGNORECASE|re.UNICODE),
#  'jennings': re.compile(r'caleb jennings|jennings|calebjennings',
#  re.IGNORECASE|re.UNICODE),
#  'smyre': re.compile(r'calvin smyre|smyre|calvinsmyre',
#  re.IGNORECASE|re.UNICODE),
#  'uresti': re.compile(r'carlos uresti|uresti|carlosuresti',
#  re.IGNORECASE|re.UNICODE),
#  'schwertner': re.compile(r'charles schwertner|schwertner|charlesschwertner',
#  re.IGNORECASE|re.UNICODE),
#  'hallowell': re.compile(r'charlie hallowell|hallowell|charliehallowell',
#  re.IGNORECASE|re.UNICODE),
#  'walk': re.compile(r'charlie walk|walk|charliewalk',
#  re.IGNORECASE|re.UNICODE),
#  'finlay': re.compile(r'chase finlay|finlay|chasefinlay',
#  re.IGNORECASE|re.UNICODE),
#  'sacca': re.compile(r'chris sacca|sacca|chrissacca',
#  re.IGNORECASE|re.UNICODE),
#  'savino': re.compile(r'chris savino|savino|chrissavino',
#  re.IGNORECASE|re.UNICODE),
#  'rodriguez': re.compile(r'christian rodriguez|rodriguez|christianrodriguez',
#  re.IGNORECASE|re.UNICODE),
#  'johnson': re.compile(r'dan johnson|johnson|danjohnson',
#  re.IGNORECASE|re.UNICODE),
#  'lewandowski': re.compile(r'corey lewandowski|lewandowski|coreylewandowski',
#  re.IGNORECASE|re.UNICODE),
#  'harmon': re.compile(r'dan harmon|harmon|danharmon',
#  re.IGNORECASE|re.UNICODE),
#  'handler': re.compile(r'daniel handler|handler|danielhandler',
#  re.IGNORECASE|re.UNICODE),
#  'masterson': re.compile(r'danny masterson|masterson|dannymasterson',
#  re.IGNORECASE|re.UNICODE),
#  'mcclure': re.compile(r'dave mcclure|mcclure|davemcclure',
#  re.IGNORECASE|re.UNICODE),
#  'bellemere': re.compile(r'david bellemere|bellemere|davidbellemere',
#  re.IGNORECASE|re.UNICODE),
#  'blaine': re.compile(r'david blaine|blaine|davidblaine',
#  re.IGNORECASE|re.UNICODE),
#  'corn': re.compile(r'david corn|corn|davidcorn', re.IGNORECASE|re.UNICODE),
#  'keyes': re.compile(r'david keyes|keyes|davidkeyes',
#  re.IGNORECASE|re.UNICODE),
#  'marchant': re.compile(r'david marchant|marchant|davidmarchant',
#  re.IGNORECASE|re.UNICODE),
#  'candappa': re.compile(r'dayan candappa|candappa|dayancandappa',
#  re.IGNORECASE|re.UNICODE),
#  'hazen': re.compile(r'don hazen|hazen|donhazen', re.IGNORECASE|re.UNICODE),
#  'mcnabb': re.compile(r'donovan mcnabb|mcnabb|donovanmcnabb',
#  re.IGNORECASE|re.UNICODE),
#  'marshall': re.compile(r'dwayne duron marshall|duron|marshall|dwayneduronmarshall',
#  re.IGNORECASE|re.UNICODE),
#  'howard': re.compile(r'dylan howard|howard|dylanhoward',
#  re.IGNORECASE|re.UNICODE),
#  'crane': re.compile(r'ed crane|crane|edcrane', re.IGNORECASE|re.UNICODE),
#  'murray': re.compile(r'ed murray|murray|edmurray', re.IGNORECASE|re.UNICODE),
#  'berganza': re.compile(r'eddie berganza|berganza|eddieberganza',
#  re.IGNORECASE|re.UNICODE),
#  'bauman': re.compile(r'eric bauman|bauman|ericbauman',
#  re.IGNORECASE|re.UNICODE),
#  'weinberger': re.compile(r'eric weinberger|weinberger|ericweinberger',
#  re.IGNORECASE|re.UNICODE),
#  'guerrero': re.compile(r'erick guerrero|guerrero|erickguerrero',
#  re.IGNORECASE|re.UNICODE),
#  'kath': re.compile(r'ethan kath|kath|ethankath', re.IGNORECASE|re.UNICODE),
#  'ayala': re.compile(r'francisco ayala|ayala|franciscoayala',
#  re.IGNORECASE|re.UNICODE),
#  'shaw': re.compile(r'frankie shaw|shaw|frankieshaw',
#  re.IGNORECASE|re.UNICODE),
#  'goddard': re.compile(r'gary goddard|goddard|garygoddard',
#  re.IGNORECASE|re.UNICODE),
#  'rush': re.compile(r'geoffrey rush|rush|geoffreyrush',
#  re.IGNORECASE|re.UNICODE),
#  'tyndall': re.compile(r'george tyndall|tyndall|georgetyndall',
#  re.IGNORECASE|re.UNICODE),
#  'kadel': re.compile(r'greg kadel|kadel|gregkadel', re.IGNORECASE|re.UNICODE),
#  'belove': re.compile(r'hadrian belove|belove|hadrianbelove',
#  re.IGNORECASE|re.UNICODE),
#  'knowles': re.compile(r'harry knowles|knowles|harryknowles',
#  re.IGNORECASE|re.UNICODE),
#  'evans': re.compile(r'heath evans|evans|heathevans',
#  re.IGNORECASE|re.UNICODE),
#  'taylor': re.compile(r'ike taylor|taylor|iketaylor',
#  re.IGNORECASE|re.UNICODE),
#  'wenner': re.compile(r'jann wenner|wenner|jannwenner',
#  re.IGNORECASE|re.UNICODE),
#  'mojica': re.compile(r'jason mojica|mojica|jasonmojica',
#  re.IGNORECASE|re.UNICODE),
#  'franklin': re.compile(r'jeff franklin|franklin|jefffranklin',
#  re.IGNORECASE|re.UNICODE),
#  'kruse': re.compile(r'jeff kruse|kruse|jeffkruse', re.IGNORECASE|re.UNICODE),
#  'tambor': re.compile(r'jeffrey tambor|tambor|jeffreytambor',
#  re.IGNORECASE|re.UNICODE),
#  'tooker': re.compile(r'jeremy tooker|tooker|jeremytooker',
#  re.IGNORECASE|re.UNICODE),
#  'kramer': re.compile(r'joel kramer|kramer|joelkramer',
#  re.IGNORECASE|re.UNICODE),
#  'hockenberry': re.compile(r'john hockenberry|hockenberry|johnhockenberry',
#  re.IGNORECASE|re.UNICODE),
#  'kenneally': re.compile(r'john kenneally|kenneally|johnkenneally',
#  re.IGNORECASE|re.UNICODE),
#  'kricfalusi': re.compile(r'john kricfalusi|kricfalusi|johnkricfalusi',
#  re.IGNORECASE|re.UNICODE),
#  'heely': re.compile(r'jon heely|heely|jonheely', re.IGNORECASE|re.UNICODE),
#  'caldbeck': re.compile(r'justin caldbeck|caldbeck|justincaldbeck',
#  re.IGNORECASE|re.UNICODE),
#  'larsen': re.compile(r'kaj larsen|larsen|kajlarsen',
#  re.IGNORECASE|re.UNICODE),
#  'templer': re.compile(r'karl templer|templer|karltempler',
#  re.IGNORECASE|re.UNICODE),
#  'baker': re.compile(r'ken baker|baker|kenbaker', re.IGNORECASE|re.UNICODE),
#  'braun': re.compile(r'kevin braun|braun|kevinbraun',
#  re.IGNORECASE|re.UNICODE),
#  'guilfoyle': re.compile(r'kimberly guilfoyle|guilfoyle|kimberlyguilfoyle',
#  re.IGNORECASE|re.UNICODE),
#  'webster': re.compile(r'kirt webster|webster|kirtwebster',
#  re.IGNORECASE|re.UNICODE),
#  'nassar': re.compile(r'larry nassar|nassar|larrynassar',
#  re.IGNORECASE|re.UNICODE),
#  'trier': re.compile(r'lars von trier|von|trier|larsvontrier',
#  re.IGNORECASE|re.UNICODE),
#  'krauss': re.compile(r'lawrence krauss|krauss|lawrencekrauss',
#  re.IGNORECASE|re.UNICODE),
#  'steele': re.compile(r'lockhart steele|steele|lockhartsteele',
#  re.IGNORECASE|re.UNICODE),
#  'stein': re.compile(r'lorin stein|stein|lorinstein',
#  re.IGNORECASE|re.UNICODE),
#  'mellor': re.compile(r'mark mellor|mellor|markmellor',
#  re.IGNORECASE|re.UNICODE),
#  'schwahn': re.compile(r'mark schwahn|schwahn|markschwahn',
#  re.IGNORECASE|re.UNICODE),
#  'faulk': re.compile(r'marshall faulk|faulk|marshallfaulk',
#  re.IGNORECASE|re.UNICODE),
#  'zimmerman': re.compile(r'matt zimmerman|zimmerman|mattzimmerman',
#  re.IGNORECASE|re.UNICODE),
#  'weiner': re.compile(r'matthew weiner|weiner|matthewweiner',
#  re.IGNORECASE|re.UNICODE),
#  'ogden': re.compile(r'max ogden|ogden|maxogden', re.IGNORECASE|re.UNICODE),
#  'martinez': re.compile(r'melanie martinez|martinez|melaniemartinez',
#  re.IGNORECASE|re.UNICODE),
#  'hafford': re.compile(r'michael hafford|hafford|michaelhafford',
#  re.IGNORECASE|re.UNICODE),
#  'weatherly': re.compile(r'michael weatherly|weatherly|michaelweatherly',
#  re.IGNORECASE|re.UNICODE),
#  'germano': re.compile(r'mike germano|germano|mikegermano',
#  re.IGNORECASE|re.UNICODE),
#  'isabella': re.compile(r'mike isabella|isabella|mikeisabella',
#  re.IGNORECASE|re.UNICODE),
#  'muqtar': re.compile(r'mohamed muqtar|muqtar|mohamedmuqtar',
#  re.IGNORECASE|re.UNICODE),
#  'miller': re.compile(r'murray miller|miller|murraymiller',
#  re.IGNORECASE|re.UNICODE),
#  'tyson': re.compile(r'neil degrasse tyson|degrasse|tyson|neildegrassetyson',
#  re.IGNORECASE|re.UNICODE),
#  'kettle': re.compile(r'nicholas kettle|kettle|nicholaskettle',
#  re.IGNORECASE|re.UNICODE),
#  'nixon': re.compile(r'nicholas nixon|nixon|nicholasnixon',
#  re.IGNORECASE|re.UNICODE),
#  'caporella': re.compile(r'nick caporella|caporella|nickcaporella',
#  re.IGNORECASE|re.UNICODE),
#  'carter': re.compile(r'nick carter|carter|nickcarter',
#  re.IGNORECASE|re.UNICODE),
#  'sauer': re.compile(r'nick sauer|sauer|nicksauer', re.IGNORECASE|re.UNICODE),
#  'stone': re.compile(r'oliver stone|stone|oliverstone',
#  re.IGNORECASE|re.UNICODE),
#  'demarchelier': re.compile(r'patrick demarchelier|demarchelier|patrickdemarchelier',
#  re.IGNORECASE|re.UNICODE),
#  'witty': re.compile(r'patrick witty|witty|patrickwitty',
#  re.IGNORECASE|re.UNICODE),
#  'marciano': re.compile(r'paul marciano|marciano|paulmarciano',
#  re.IGNORECASE|re.UNICODE),
#  'shapiro': re.compile(r'paul shapiro|shapiro|paulshapiro',
#  re.IGNORECASE|re.UNICODE),
#  'whalen': re.compile(r'paul whalen|whalen|paulwhalen',
#  re.IGNORECASE|re.UNICODE),
#  'berk': re.compile(r'philip berk|berk|philipberk', re.IGNORECASE|re.UNICODE),
#  'bocanegra': re.compile(r'raul bocanegra|bocanegra|raulbocanegra',
#  re.IGNORECASE|re.UNICODE),
#  'james': re.compile(r'rhys james|james|rhysjames', re.IGNORECASE|re.UNICODE),
#  'devaul': re.compile(r'richard devaul|devaul|richarddevaul',
#  re.IGNORECASE|re.UNICODE),
#  'day': re.compile(r'rick day|day|rickday', re.IGNORECASE|re.UNICODE),
#  'knepper': re.compile(r'robert knepper|knepper|robertknepper',
#  re.IGNORECASE|re.UNICODE),
#  'reece': re.compile(r'robert reece|reece|robertreece',
#  re.IGNORECASE|re.UNICODE),
#  'scoble': re.compile(r'robert scoble|scoble|robertscoble',
#  re.IGNORECASE|re.UNICODE),
#  'carlson': re.compile(r'ron carlson|carlson|roncarlson',
#  re.IGNORECASE|re.UNICODE),
#  'jeremy': re.compile(r'ron jeremy|jeremy|ronjeremy',
#  re.IGNORECASE|re.UNICODE),
#  'levinsohn': re.compile(r'ross levinsohn|levinsohn|rosslevinsohn',
#  re.IGNORECASE|re.UNICODE),
#  'price': re.compile(r'roy price|price|royprice', re.IGNORECASE|re.UNICODE),
#  'simmons': re.compile(r'russell simmons|simmons|russellsimmons',
#  re.IGNORECASE|re.UNICODE),
#  'isaly': re.compile(r'sam isaly|isaly|samisaly', re.IGNORECASE|re.UNICODE),
#  'courtney': re.compile(r'scott courtney|courtney|scottcourtney',
#  re.IGNORECASE|re.UNICODE),
#  'hannity': re.compile(r'sean hannity|hannity|seanhannity',
#  re.IGNORECASE|re.UNICODE),
#  'hutchison': re.compile(r'sean hutchison|hutchison|seanhutchison',
#  re.IGNORECASE|re.UNICODE),
#  'sabal': re.compile(r'seth sabal|sabal|sethsabal', re.IGNORECASE|re.UNICODE),
#  'elnashai': re.compile(r'shadie elnashai|elnashai|shadieelnashai',
#  re.IGNORECASE|re.UNICODE),
#  'pishevar': re.compile(r'shervin pishevar|pishevar|shervinpishevar',
#  re.IGNORECASE|re.UNICODE),
#  'lee': re.compile(r'stan lee|lee|stanlee', re.IGNORECASE|re.UNICODE),
#  'butts': re.compile(r'steve butts|butts|stevebutts',
#  re.IGNORECASE|re.UNICODE),
#  'striegel': re.compile(r'steven wilder striegel|wilder|striegel|stevenwilderstriegel',
#  re.IGNORECASE|re.UNICODE),
#  'stallone': re.compile(r'sylvester stallone|stallone|sylvesterstallone',
#  re.IGNORECASE|re.UNICODE),
#  'ussery': re.compile(r'terdema ussery|ussery|terdemaussery',
#  re.IGNORECASE|re.UNICODE),
#  'heatherton': re.compile(r'todd heatherton|heatherton|toddheatherton',
#  re.IGNORECASE|re.UNICODE),
#  'ashbrook': re.compile(r'tom ashbrook|ashbrook|tomashbrook',
#  re.IGNORECASE|re.UNICODE),
#  'mendoza': re.compile(r'tony mendoza|mendoza|tonymendoza',
#  re.IGNORECASE|re.UNICODE),
#  'kalanick': re.compile(r'travis kalanick|kalanick|traviskalanick',
#  re.IGNORECASE|re.UNICODE),
#  'grasham': re.compile(r'tyler grasham|grasham|tylergrasham',
#  re.IGNORECASE|re.UNICODE),
#  'ingenito': re.compile(r'vince ingenito|ingenito|vinceingenito',
#  re.IGNORECASE|re.UNICODE),
#  'cirrincione': re.compile(r'vincent cirrincione|cirrincione|vincentcirrincione',
#  re.IGNORECASE|re.UNICODE),
#  'pacelle': re.compile(r'wayne pacelle|pacelle|waynepacelle',
#  re.IGNORECASE|re.UNICODE),
#  'goodman': re.compile(r'wesley goodman|goodman|wesleygoodman',
#  re.IGNORECASE|re.UNICODE),
#  'jacoby': re.compile(r'william jacoby|jacoby|williamjacoby',
#  re.IGNORECASE|re.UNICODE),
#  'kelley': re.compile(r'william kelley|kelley|williamkelley',
#  re.IGNORECASE|re.UNICODE),
#  'ck': re.compile(r'louis ck|louis c.k.|louisck|louisc.k.',
#  re.IGNORECASE|re.UNICODE)}

# %%
tweetPrep.targ_dic.keys()
# Out:
# dict_keys(['hoffman', 'landesman', 'nelly', 'toback', 'lebsock', 'harvey_weinstein', 'franken', 'mack', 'ramsey', 'rubin', 'argento', 'ansari', 'affleck', 'vereen', 'bob_weinstein', 'tinsley', 'kavanaugh', 'ratner', 'weber', 'singer', 'payne', 'rose', 'hardwick', 'wilson', 'coleman', 'ronaldo', 'garcia', 'hill', 'zwerdling', 'copperfield', 'parneros', 'trump', 'westwick', 'bolling', 'greitens', 'schneiderman', 'keillor', 'takei', 'depardieu', 'thrush', 'fish', 'horovitz', 'franco', 'levine', 'rosen', 'piven', 'lacey', 'besh', 'conyers', 'lasseter', 'schwartz', 'raniere', 'friedman', 'spacey', 'wieseltier', 'lopate', 'moonves', 'besson', 'batali', 'testino', 'halperin', 'dababneh', 'lauer', 'watt', 'douglas', 'feinberg', 'ferro', 'oreskes', 'freeman', 'spurlock', 'meehan', 'haggis', 'martins', 'dreyfuss', 'polanski', 'moore', 'lizza', 'seacrest', 'baio', 'alexie', 'wynn', 'seagal', 'smiley', 'brokaw', 'frieden', 'sizemore', 'franks', 'strampel', 'venit', 'carrasquillo', 'schultz', 'klein', 'jones', 'kozinski', 'vann', 'singhal', 'passos', 'creighton', 'kreisberg', 'dick', 'henry', 'savage', 'kratochvil', 'kratochvil (ext.)', 'ronell', 'lubin', 'sparks', 'strong', 'hybels', 'farenthold', 'scott', 'miles', 'kern', 'strider', 'jennings', 'smyre', 'uresti', 'schwertner', 'hallowell', 'walk', 'finlay', 'sacca', 'savino', 'rodriguez', 'johnson', 'lewandowski', 'harmon', 'handler', 'masterson', 'mcclure', 'bellemere', 'blaine', 'corn', 'keyes', 'marchant', 'candappa', 'hazen', 'mcnabb', 'marshall', 'howard', 'crane', 'murray', 'berganza', 'bauman', 'weinberger', 'guerrero', 'kath', 'ayala', 'shaw', 'goddard', 'rush', 'tyndall', 'kadel', 'belove', 'knowles', 'evans', 'taylor', 'wenner', 'mojica', 'franklin', 'kruse', 'tambor', 'tooker', 'kramer', 'hockenberry', 'kenneally', 'kricfalusi', 'heely', 'caldbeck', 'larsen', 'templer', 'baker', 'braun', 'guilfoyle', 'webster', 'nassar', 'trier', 'krauss', 'steele', 'stein', 'mellor', 'schwahn', 'faulk', 'zimmerman', 'weiner', 'ogden', 'martinez', 'hafford', 'weatherly', 'germano', 'isabella', 'muqtar', 'miller', 'tyson', 'kettle', 'nixon', 'caporella', 'carter', 'sauer', 'stone', 'demarchelier', 'witty', 'marciano', 'shapiro', 'whalen', 'berk', 'bocanegra', 'james', 'devaul', 'day', 'knepper', 'reece', 'scoble', 'carlson', 'jeremy', 'levinsohn', 'price', 'simmons', 'isaly', 'courtney', 'hannity', 'hutchison', 'sabal', 'elnashai', 'pishevar', 'lee', 'butts', 'striegel', 'stallone', 'ussery', 'heatherton', 'ashbrook', 'mendoza', 'kalanick', 'grasham', 'ingenito', 'cirrincione', 'pacelle', 'goodman', 'jacoby', 'kelley', 'ck'])

# %%
len(tweetPrep.targ_dic)
# Out:
# 242

# %%
all_targets_list
# Out:
# [['dustin_hoffman', 'dustin hoffman'],
#  ['knight_landesman', 'knight landesman'],
#  'nelly',
#  ['james_toback', 'james toback'],
#  ['steve_lebsock', 'steve lebsock'],
#  ['harvey_weinstein', 'harvey weinstein'],
#  ['al_franken', 'al franken'],
#  ['allison_mack', 'allison mack'],
#  ['andrea_ramsey', 'andrea ramsey'],
#  ['andy_rubin', 'andy rubin'],
#  ['asia_argento', 'asia argento'],
#  ['aziz_ansari', 'aziz ansari'],
#  ['ben_affleck', 'ben affleck'],
#  ['ben_vereen', 'ben vereen'],
#  ['bob_weinstein', 'bob weinstein'],
#  ['boyd_tinsley', 'boyd tinsley'],
#  ['brett_kavanaugh', 'brett kavanaugh'],
#  ['brett_ratner', 'brett ratner'],
#  ['bruce_weber', 'bruce weber'],
#  ['bryan_singer', 'bryan singer'],
#  ['charles_payne', 'charles payne'],
#  ['charlie_rose', 'charlie rose'],
#  ['chris_hardwick', 'chris hardwick'],
#  ['cody_wilson', 'cody wilson'],
#  ['corey_coleman', 'corey coleman'],
#  ['cristiano_ronaldo', 'cristiano ronaldo'],
#  ['cristina_garcia', 'cristina garcia'],
#  ['curtis_hill', 'curtis hill'],
#  ['daniel_zwerdling', 'daniel zwerdling'],
#  ['david_copperfield', 'david copperfield'],
#  ['demos_parneros', 'demos parneros'],
#  ['donald_trump', 'donald trump'],
#  ['ed_westwick', 'ed westwick'],
#  ['eric_bolling', 'eric bolling'],
#  ['eric_greitens', 'eric greitens'],
#  ['eric_schneiderman', 'eric schneiderman'],
#  ['garrison_keillor', 'garrison keillor'],
#  ['george_takei', 'george takei'],
#  ['gerard_depardieu', 'gerard depardieu'],
#  ['glenn_thrush', 'glenn thrush'],
#  ['hamilton_fish', 'hamilton fish'],
#  ['israel_horovitz', 'israel horovitz'],
#  ['james_franco', 'james franco'],
#  ['james_levine', 'james levine'],
#  ['james_rosen', 'james rosen'],
#  ['jeremy_piven', 'jeremy piven'],
#  ['jesse_lacey', 'jesse lacey'],
#  ['john_besh', 'john besh'],
#  ['john_conyers', 'john conyers'],
#  ['john_lasseter', 'john lasseter'],
#  ['jonathan_schwartz', 'jonathan schwartz'],
#  ['keith_raniere', 'keith raniere'],
#  ['ken_friedman', 'ken friedman'],
#  ['kevin_spacey', 'kevin spacey'],
#  ['leon_wieseltier', 'leon wieseltier'],
#  ['leonard_lopate', 'leonard lopate'],
#  ['les_moonves', 'les moonves'],
#  ['luc_besson', 'luc besson'],
#  ['mario_batali', 'mario batali'],
#  ['mario_testino', 'mario testino'],
#  ['mark_halperin', 'mark halperin'],
#  ['matt_dababneh', 'matt dababneh'],
#  ['matt_lauer', 'matt lauer'],
#  ['mel_watt', 'mel watt'],
#  ['michael_douglas', 'michael douglas'],
#  ['michael_feinberg', 'michael feinberg'],
#  ['michael_ferro', 'michael ferro'],
#  ['michael_oreskes', 'michael oreskes'],
#  ['morgan_freeman', 'morgan freeman'],
#  ['morgan_spurlock', 'morgan spurlock'],
#  ['patrick_meehan', 'patrick meehan'],
#  ['paul_haggis', 'paul haggis'],
#  ['peter_martins', 'peter martins'],
#  ['richard_dreyfuss', 'richard dreyfuss'],
#  ['roman_polanski', 'roman polanski'],
#  ['roy_moore', 'roy moore'],
#  ['ryan_lizza', 'ryan lizza'],
#  ['ryan_seacrest', 'ryan seacrest'],
#  ['scott_baio', 'scott baio'],
#  ['sherman_alexie', 'sherman alexie'],
#  ['steve_wynn', 'steve wynn'],
#  ['steven_seagal', 'steven seagal'],
#  ['tavis_smiley', 'tavis smiley'],
#  ['tom_brokaw', 'tom brokaw'],
#  ['tom_frieden', 'tom frieden'],
#  ['tom_sizemore', 'tom sizemore'],
#  ['trent_franks', 'trent franks'],
#  ['william_strampel', 'william strampel'],
#  ['adam_venit', 'adam venit'],
#  ['adrian_carrasquillo', 'adrian carrasquillo'],
#  ['albert_schultz', 'albert schultz'],
#  ['alec_klein', 'alec klein'],
#  ['alex_jones', 'alex jones'],
#  ['alex_kozinski', 'alex kozinski'],
#  ['ameer_vann', 'ameer vann'],
#  ['amit_singhal', 'amit singhal'],
#  ['andre_passos', 'andre passos'],
#  ['andrew_creighton', 'andrew creighton'],
#  ['andrew_kreisberg', 'andrew kreisberg'],
#  ['andy_dick', 'andy dick'],
#  ['andy_henry', 'andy henry'],
#  ['andy_savage', 'andy savage'],
#  ['antonin_kratochvil', 'antonin kratochvil'],
#  ['antonin_kratochvil (ext.)', 'antonin kratochvil (ext.)'],
#  ['avital_ronell', 'avital ronell'],
#  ['barry_lubin', 'barry lubin'],
#  ['benjamin_sparks', 'benjamin sparks'],
#  ['benton_strong', 'benton strong'],
#  ['bill_hybels', 'bill hybels'],
#  ['blake_farenthold', 'blake farenthold'],
#  ['bobby_scott', 'bobby scott'],
#  ['borris_miles', 'borris miles'],
#  ['brad_kern', 'brad kern'],
#  ['burns_strider', 'burns strider'],
#  ['caleb_jennings', 'caleb jennings'],
#  ['calvin_smyre', 'calvin smyre'],
#  ['carlos_uresti', 'carlos uresti'],
#  ['charles_schwertner', 'charles schwertner'],
#  ['charlie_hallowell', 'charlie hallowell'],
#  ['charlie_walk', 'charlie walk'],
#  ['chase_finlay', 'chase finlay'],
#  ['chris_sacca', 'chris sacca'],
#  ['chris_savino', 'chris savino'],
#  ['christian_rodriguez', 'christian rodriguez'],
#  ['clay_johnson', 'clay johnson'],
#  ['corey_lewandowski', 'corey lewandowski'],
#  ['dan_harmon', 'dan harmon'],
#  ['dan_johnson', 'dan johnson'],
#  ['daniel_handler', 'daniel handler'],
#  ['danny_masterson', 'danny masterson'],
#  ['dave_mcclure', 'dave mcclure'],
#  ['david_bellemere', 'david bellemere'],
#  ['david_blaine', 'david blaine'],
#  ['david_corn', 'david corn'],
#  ['david_keyes', 'david keyes'],
#  ['david_marchant', 'david marchant'],
#  ['dayan_candappa', 'dayan candappa'],
#  ['don_hazen', 'don hazen'],
#  ['donovan_mcnabb', 'donovan mcnabb'],
#  ['dustin_marshall', 'dustin marshall'],
#  ['dwayne_duron_marshall', 'dwayne duron marshall'],
#  ['dylan_howard', 'dylan howard'],
#  ['ed_crane', 'ed crane'],
#  ['ed_murray', 'ed murray'],
#  ['eddie_berganza', 'eddie berganza'],
#  ['eric_bauman', 'eric bauman'],
#  ['eric_weinberger', 'eric weinberger'],
#  ['erick_guerrero', 'erick guerrero'],
#  ['ethan_kath', 'ethan kath'],
#  ['francisco_ayala', 'francisco ayala'],
#  ['frankie_shaw', 'frankie shaw'],
#  ['gary_goddard', 'gary goddard'],
#  ['geoffrey_rush', 'geoffrey rush'],
#  ['george_tyndall', 'george tyndall'],
#  ['greg_kadel', 'greg kadel'],
#  ['hadrian_belove', 'hadrian belove'],
#  ['harry_knowles', 'harry knowles'],
#  ['heath_evans', 'heath evans'],
#  ['howie_rubin', 'howie rubin'],
#  ['ike_taylor', 'ike taylor'],
#  ['jann_wenner', 'jann wenner'],
#  ['jason_mojica', 'jason mojica'],
#  ['jeff_franklin', 'jeff franklin'],
#  ['jeff_kruse', 'jeff kruse'],
#  ['jeffrey_klein', 'jeffrey klein'],
#  ['jeffrey_tambor', 'jeffrey tambor'],
#  ['jeremy_tooker', 'jeremy tooker'],
#  ['joel_kramer', 'joel kramer'],
#  ['john_hockenberry', 'john hockenberry'],
#  ['john_kenneally', 'john kenneally'],
#  ['john_kricfalusi', 'john kricfalusi'],
#  ['jon_heely', 'jon heely'],
#  ['justin_caldbeck', 'justin caldbeck'],
#  ['kaj_larsen', 'kaj larsen'],
#  ['karl_templer', 'karl templer'],
#  ['ken_baker', 'ken baker'],
#  ['kevin_braun', 'kevin braun'],
#  ['kimberly_guilfoyle', 'kimberly guilfoyle'],
#  ['kirt_webster', 'kirt webster'],
#  ['larry_nassar', 'larry nassar'],
#  ['lars_von_trier', 'lars von trier'],
#  ['lawrence_krauss', 'lawrence krauss'],
#  ['lockhart_steele', 'lockhart steele'],
#  ['lorin_stein', 'lorin stein'],
#  ['mark_mellor', 'mark mellor'],
#  ['mark_schwahn', 'mark schwahn'],
#  ['marshall_faulk', 'marshall faulk'],
#  ['matt_zimmerman', 'matt zimmerman'],
#  ['matthew_weiner', 'matthew weiner'],
#  ['max_ogden', 'max ogden'],
#  ['melanie_martinez', 'melanie martinez'],
#  ['michael_hafford', 'michael hafford'],
#  ['michael_weatherly', 'michael weatherly'],
#  ['mike_germano', 'mike germano'],
#  ['mike_isabella', 'mike isabella'],
#  ['mohamed_muqtar', 'mohamed muqtar'],
#  ['murray_miller', 'murray miller'],
#  ['neil_degrasse_tyson', 'neil degrasse tyson'],
#  ['nicholas_kettle', 'nicholas kettle'],
#  ['nicholas_nixon', 'nicholas nixon'],
#  ['nick_caporella', 'nick caporella'],
#  ['nick_carter', 'nick carter'],
#  ['nick_sauer', 'nick sauer'],
#  ['oliver_stone', 'oliver stone'],
#  ['patrick_demarchelier', 'patrick demarchelier'],
#  ['patrick_witty', 'patrick witty'],
#  ['paul_marciano', 'paul marciano'],
#  ['paul_shapiro', 'paul shapiro'],
#  ['paul_whalen', 'paul whalen'],
#  ['philip_berk', 'philip berk'],
#  ['raul_bocanegra', 'raul bocanegra'],
#  ['rhys_james', 'rhys james'],
#  ['richard_devaul', 'richard devaul'],
#  ['rick_day', 'rick day'],
#  ['robert_knepper', 'robert knepper'],
#  ['robert_moore', 'robert moore'],
#  ['robert_reece', 'robert reece'],
#  ['robert_scoble', 'robert scoble'],
#  ['ron_carlson', 'ron carlson'],
#  ['ron_jeremy', 'ron jeremy'],
#  ['ross_levinsohn', 'ross levinsohn'],
#  ['roy_price', 'roy price'],
#  ['russell_simmons', 'russell simmons'],
#  ['sam_isaly', 'sam isaly'],
#  ['scott_courtney', 'scott courtney'],
#  ['sean_hannity', 'sean hannity'],
#  ['sean_hutchison', 'sean hutchison'],
#  ['seth_sabal', 'seth sabal'],
#  ['shadie_elnashai', 'shadie elnashai'],
#  ['shervin_pishevar', 'shervin pishevar'],
#  ['stan_lee', 'stan lee'],
#  ['steve_butts', 'steve butts'],
#  ['steven_wilder_striegel', 'steven wilder striegel'],
#  ['sylvester_stallone', 'sylvester stallone'],
#  ['terdema_ussery', 'terdema ussery'],
#  ['todd_heatherton', 'todd heatherton'],
#  ['tom_ashbrook', 'tom ashbrook'],
#  ['tony_mendoza', 'tony mendoza'],
#  ['travis_kalanick', 'travis kalanick'],
#  ['tyler_grasham', 'tyler grasham'],
#  ['vince_ingenito', 'vince ingenito'],
#  ['vincent_cirrincione', 'vincent cirrincione'],
#  ['wayne_pacelle', 'wayne pacelle'],
#  ['wesley_goodman', 'wesley goodman'],
#  ['william_jacoby', 'william jacoby'],
#  ['william_kelley', 'william kelley']]
