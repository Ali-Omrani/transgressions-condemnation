# %%
# !pip install Unidecode
# Out:
# ...
#      |████████████████████████████████| 235 kB 1.1 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.1.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/geev/Research/in_progress/Transgressions/transgressions-env/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install names_dataset
# Out:
# ...
#      |████████████████████████████████| 58.4 MB 24.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 10.1 MB 16.1 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for names-dataset: filename=names_dataset-3.0.2-py3-none-any.whl size=116832287 sha256=5d89cddf1db2d57873040c289df0b4d6e1c1b63f903f54cd9dcb539be3eaae21
#   Stored in directory: /home/geev/.cache/pip/wheels/51/a9/74/ab133c364dba04cc00c2d86e07f76ce1796539e3b8e24bc2cf
# ...
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681845 sha256=1d00791080d807a13f21980e94c08ce79b716ee46db35c9b6ec24372a2f6e18d
#   Stored in directory: /home/geev/.cache/pip/wheels/81/2e/84/0aff7999dc68fdfeee5c31db245dc3e43cec9d957d1063375e
# Successfully built names-dataset pycountry
# ...
# WARNING: You are using pip version 21.1.3; however, version 21.3.1 is available.
# ...

# %%
import pandas as pd
import pickle
import json
from names_dataset import NameDataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-be6401b3eb46> in <module>
#       2 import pickle
#       3 import json
# ----> 4 from names_dataset import NameDataset
#
# ModuleNotFoundError: No module named 'names_dataset'

# %%
target_dic = {}
target_dic['nassar'] = {'fn': 'larry', 'ln': 'nassar', 'handle': '@larrynassar'}
target_dic['landesman'] = {'fn': 'knight', 'ln': 'landesman', 'handle': '@knightlandesman'}
target_dic['masterson'] = {'fn': 'danny', 'ln': 'masterson', 'handle': '@dannymasterson'}
target_dic['affleck'] = {'fn': 'ben', 'ln': 'affleck', 'handle': '@BenAffleck'}
target_dic['scoble'] = {'fn': 'robert', 'ln': 'scoble', 'handle': '@Scobleizer'}
target_dic['schwahn'] = {'fn': 'mark', 'ln': 'schwahn', 'handle': '@MarkSchwan'}
target_dic['venit'] = {'fn': 'adam', 'ln': 'venit', 'handle': '@AdamVenit'}
target_dic['berganza'] = {'fn': 'eddie', 'ln': 'berganza', 'handle': '@EddieBerganza'}
target_dic['seagal'] = {'fn': 'steven', 'ln': 'seagal', 'handle': '@sseagalofficial'}
target_dic['goddard'] = {'fn': 'gary', 'ln': 'goddard', 'handle': '@GaryGoddardAgy'}
target_dic['hafford'] = {'fn': 'michael', 'ln': 'hafford', 'handle': '@michaelhafford'}
target_dic['halperin'] = {'fn': 'mark', 'ln': 'halperin', 'handle': '@MarkHalperin'}
target_dic['smyre'] = {'fn': 'calvin', 'ln': 'smyre', 'handle': '@CalvinSmyre'}
target_dic['lebsock'] = {'fn': 'steve', 'ln': 'lebsock', 'handle': '@RepLebsock'}
target_dic['weinstein'] = {'fn': 'harvey', 'ln': 'weinstein', 'handle': '@HarveyWeinstein'}
target_dic['bob_weinstein'] = {'fn': 'bob', 'ln': 'weinstein', 'handle': '@BobWeinstein'}
target_dic['ingenito'] = {'fn': 'vince', 'ln': 'ingenito', 'handle': '@Vincogneato'}
target_dic['spacey'] = {'fn': 'kevin', 'ln': 'spacey', 'handle': '@KevinSpacey'}
target_dic['kreisberg'] = {'fn': 'andrew', 'ln': 'kreisberg', 'handle': '@AJKreisberg'}
target_dic['grasham'] = {'fn': 'tyler', 'ln': 'grasham', 'handle': '@TylerGrasham'}
target_dic['wieseltier'] = {'fn': 'leon', 'ln': 'wieseltier', 'handle': '@leonwieseltier'}
target_dic['knepper'] = {'fn': 'robert', 'ln': 'knepper', 'handle': '@robert_knepper'}
target_dic['ratner'] = {'fn': 'brett', 'ln': 'ratner', 'handle': '@BrettRatner'}
target_dic['ken_baker'] = {'fn': 'ken', 'ln': 'baker', 'handle': '@kenbakernow'}
target_dic['toback'] = {'fn': 'james', 'ln': 'toback', 'handle': '@JamesToback'}
target_dic['dreyfuss'] = {'fn': 'richard', 'ln': 'dreyfuss', 'handle': '@RichardDreyfuss'}
target_dic['piven'] = {'fn': 'jeremy', 'ln': 'piven', 'handle': '@jeremypiven'}
target_dic['weiner'] = {'fn': 'matthew', 'ln': 'weiner', 'handle': '@mathewweiner'}
target_dic['takei'] = {'fn': 'george', 'ln': 'takei', 'handle': '@GeorgeTakei'}
target_dic['ethan_kath'] = {'fn': 'ethan', 'ln': 'kath', 'handle': '@ETHANKATH'}
target_dic['lacey'] = {'fn': 'jesse', 'ln': 'lacey', 'handle': '@JesseyLacey'}
target_dic['lockhart_steele'] = {'fn': 'lockhart', 'ln': 'steele', 'handle': '@Lock'}
target_dic['besh'] = {'fn': 'john', 'ln': 'besh', 'handle': '@chefjohnbesh'}
target_dic['bocanegra'] = {'fn': 'raul', 'ln': 'bocanegra', 'handle': '@RaulJBocanegra'}
target_dic['wenner'] = {'fn': 'jann', 'ln': 'wenner', 'handle': '@JannWenner'}
target_dic['hoffman'] = {'fn': 'dustin', 'ln': 'hoffman', 'handle': '@DustinHoffman'}
target_dic['caleb_jennings'] = {'fn': 'caleb', 'ln': 'jennings', 'handle': '@CalebJennings'}
target_dic['savino'] = {'fn': 'chris', 'ln': 'savino', 'handle': '@ChrisSavino'}
target_dic['corn'] = {'fn': 'david', 'ln': 'corn', 'handle': '@DavidCornDC'}
target_dic['oreskes'] = {'fn': 'michael', 'ln': 'oreskes', 'handle': '@MichaelOreskes'}
target_dic['mendoza'] = {'fn': 'tony', 'ln': 'mendoza', 'handle': '@TonyMendoza'}
target_dic['heatherton'] = {'fn': 'todd', 'ln': 'heatherton', 'handle': '@ToddHeatherton'}
target_dic['price'] = {'fn': 'roy', 'ln': 'price', 'handle': '@RoyPrice'}
target_dic['sizemore'] = {'fn': 'tom', 'ln': 'sizemore', 'handle': '@TomSizemore'}
target_dic['tambor'] = {'fn': 'jeffrey', 'ln': 'tambor', 'handle': '@JeffreyTambor'}
target_dic['westwick'] = {'fn': 'ed', 'ln': 'westwick', 'handle': '@EdWestwick'}
target_dic['blaine'] = {'fn': 'david', 'ln': 'blaine', 'handle': '@davidblaine'}
target_dic['moore'] = {'fn': 'roy', 'ln': 'moore', 'handle': '@RoyMoore'}



target_last_names = [target_dic[k]['ln'] for k in target_dic.keys()]

for k in target_dic.keys():
    try:
        target_dic[k]['other_exclude']
    except KeyError:
        target_dic[k]['other_exclude'] = []

target_dic['mendoza']['other_exclude'] = ['maine']
target_dic['heatherton']['other_exclude'] = ['621', '6600', 'eastbound', '652-658']

# %%
with open("../../data/target_dic.json", "r") as f:
    data = json.load(f)

# %%
# Out:
# {'nassar': {'fn': 'larry', 'ln': 'nassar', 'handle': '@larrynassar', 'other_exclude': []}, 'landesman': {'fn': 'knight', 'ln': 'landesman', 'handle': '@knightlandesman', 'other_exclude': []}, 'masterson': {'fn': 'danny', 'ln': 'masterson', 'handle': '@dannymasterson', 'other_exclude': []}, 'affleck': {'fn': 'ben', 'ln': 'affleck', 'handle': '@BenAffleck', 'other_exclude': []}, 'scoble': {'fn': 'robert', 'ln': 'scoble', 'handle': '@Scobleizer', 'other_exclude': []}, 'schwahn': {'fn': 'mark', 'ln': 'schwahn', 'handle': '@MarkSchwan', 'other_exclude': []}, 'venit': {'fn': 'adam', 'ln': 'venit', 'handle': '@AdamVenit', 'other_exclude': []}, 'berganza': {'fn': 'eddie', 'ln': 'berganza', 'handle': '@EddieBerganza', 'other_exclude': []}, 'seagal': {'fn': 'steven', 'ln': 'seagal', 'handle': '@sseagalofficial', 'other_exclude': []}, 'goddard': {'fn': 'gary', 'ln': 'goddard', 'handle': '@GaryGoddardAgy', 'other_exclude': []}, 'hafford': {'fn': 'michael', 'ln': 'hafford', 'handle': '@michaelhaf
# ...

# %%
target_dic
# Out:
# {'nassar': {'fn': 'larry',
#   'ln': 'nassar',
#   'handle': '@larrynassar',
#   'other_exclude': []},
#  'landesman': {'fn': 'knight',
#   'ln': 'landesman',
#   'handle': '@knightlandesman',
#   'other_exclude': []},
#  'masterson': {'fn': 'danny',
#   'ln': 'masterson',
#   'handle': '@dannymasterson',
#   'other_exclude': []},
#  'affleck': {'fn': 'ben',
#   'ln': 'affleck',
#   'handle': '@BenAffleck',
#   'other_exclude': []},
#  'scoble': {'fn': 'robert',
#   'ln': 'scoble',
#   'handle': '@Scobleizer',
#   'other_exclude': []},
#  'schwahn': {'fn': 'mark',
#   'ln': 'schwahn',
#   'handle': '@MarkSchwan',
#   'other_exclude': []},
#  'venit': {'fn': 'adam',
#   'ln': 'venit',
#   'handle': '@AdamVenit',
#   'other_exclude': []},
#  'berganza': {'fn': 'eddie',
#   'ln': 'berganza',
#   'handle': '@EddieBerganza',
#   'other_exclude': []},
#  'seagal': {'fn': 'steven',
#   'ln': 'seagal',
#   'handle': '@sseagalofficial',
#   'other_exclude': []},
#  'goddard': {'fn': 'gary',
# ...

# %%
targs = pd.read_csv('../../data/transgression_ambiguity_metoo_breaking_stimuli_all_targets.csv').target.values

# %%
all_targets_list = [] 
for t_name in targs:

    if not isinstance(t_name, str):
        continue
    if ("_" not in t_name):
        print("bad {}".format(t_name))
        all_targets_list.append([t_name])
        continue 
#     print(t_name)
    if len(t_name.split("_"))!=2:
        print("too long or too short", t_name)
        all_targets_list.append([t_name, " ".join(t_name.split("_"))])
        continue

    first, last = t_name.split("_")
    all_targets_list.append([t_name, " ".join([first,last])])
len(all_targets_list)
# Out:
# bad nelly
# too long or too short dwayne_duron_marshall
# too long or too short lars_von_trier
# too long or too short neil_degrasse_tyson
# too long or too short steven_wilder_striegel
# 246

# %%
all_targets_list
# Out:
# [['dustin_hoffman', 'dustin hoffman'],
#  ['knight_landesman', 'knight landesman'],
#  ['nelly'],
#  ['james_toback', 'james toback'],
#  ['steve_lebsock', 'steve lebsock'],
#  ['harvey_weinstein', 'harvey weinstein'],
#  ['al_franken', 'al franken'],
#  ['allison_mack', 'allison mack'],
#  ['andrea_ramsey', 'andrea ramsey'],
#  ['andy_rubin', 'andy rubin'],
#  ['asia_argento', 'asia argento'],
#  ['aziz_ansari', 'aziz ansari'],
#  ['ben_affleck', 'ben affleck'],
#  ['ben_vereen', 'ben vereen'],
#  ['bob_weinstein', 'bob weinstein'],
#  ['boyd_tinsley', 'boyd tinsley'],
#  ['brett_kavanaugh', 'brett kavanaugh'],
#  ['brett_ratner', 'brett ratner'],
#  ['bruce_weber', 'bruce weber'],
#  ['bryan_singer', 'bryan singer'],
#  ['charles_payne', 'charles payne'],
#  ['charlie_rose', 'charlie rose'],
#  ['chris_hardwick', 'chris hardwick'],
#  ['cody_wilson', 'cody wilson'],
#  ['corey_coleman', 'corey coleman'],
#  ['cristiano_ronaldo', 'cristiano ronaldo'],
# ...
